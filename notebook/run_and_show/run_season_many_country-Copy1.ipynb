# %%
import numpy as np
import pandas as pd
import math

pd.set_option('display.max_rows', 80)

import random
import time
import pickle

import sys
sys.path.append("../../")

from src.worldsoccer import Worldsoccer
from src.create import *
from src.print_result import *

from src.object.league import League
from src.object.proleague import ProLeague

from config.formation import *
from config.config import *

# %%
df_name = pd.read_csv("../../data/csv/NationalNames.csv")
df_name_list = list(df_name[df_name.Gender=='M'].Name.sample(10000))

# %%
team_names = pd.read_excel("../../data/excel/team_name.xlsx")

# %%
#イングランド
teams = create_team(20, team_names["premier"].values, df_name_list,
                    mean_rate=65, min_rate=72)
E1 = League(name="Premier", teams=teams,
            league_level=1,
            num=20, min_rate=75, max_rate=99, mean_rate=65,
            category='top', relegation_num=3)

teams = create_team(20, team_names['Championship'].values, df_name_list,
                    mean_rate=64, min_rate=58, max_rate=77, age_mean=26)
E2 = League(name="Championship", teams=teams,
            league_level=2,
            num=20, min_rate=58, max_rate=77, mean_rate=64,
            category='middle', relegation_num=3, promotion_num=3)

teams = create_team(20, team_names['EFL1'].values, df_name_list,
                    mean_rate=63, min_rate=47, max_rate=71, age_mean=25)
E3 = League(name="EFL1", teams=teams,
            league_level=3,
            num=20, min_rate=47, max_rate=71, mean_rate=63,
            category='lowest', promotion_num=3)

England = ProLeague(name="England", leagues=[E1, E2, E3], competition_name="FA杯")

# %%
#スペイン
teams = create_team(20, team_names["LaLiga"].values, df_name_list,
                    mean_rate=65, min_rate=72)
S1 = League(name="La Liga Santander", teams=teams,
            league_level=1,
            num=20, min_rate=75, max_rate=99, mean_rate=65,
            category='top', relegation_num=3)

teams = create_team(20, team_names['smartbank'].values, df_name_list,
                    mean_rate=64, min_rate=58, max_rate=77, age_mean=26)
S2 = League(name="La Liga SmartBank", teams=teams,
            league_level=2,
            num=20, min_rate=58, max_rate=77, mean_rate=64,
            category='middle', relegation_num=3, promotion_num=3)

teams = create_team(20, team_names['primera'].values, df_name_list,
                    mean_rate=63, min_rate=47, max_rate=71, age_mean=25)
S3 = League(name="Primera Division RFEF", teams=teams,
            league_level=3,
            num=20, min_rate=47, max_rate=71, mean_rate=63,
            category='lowest', promotion_num=3)

Spain = ProLeague(name="Spain", leagues=[S1, S2, S3], competition_name="カラバオ杯")

# %%
#ポルトガル
teams = create_team(20, team_names["LigaPortugal"].values, df_name_list,
                    mean_rate=64, min_rate=66)
P1 = League(name="Liga Portugal", teams=teams,
            league_level=2,
            num=20, min_rate=66, max_rate=81, mean_rate=64,
            category='top', relegation_num=3)

teams = create_team(20, team_names['LigaPortugal2'].values, df_name_list,
                    mean_rate=63, min_rate=43, max_rate=74, age_mean=25)
P2 = League(name="Liga Portugal2", teams=teams,
            league_level=3,
            num=20, min_rate=43, max_rate=74, mean_rate=63,
            category='lowest', promotion_num=3)

Portugal = ProLeague(name="Portugal", leagues=[P1, P2], competition_name="ポルトガル杯")

# %%
country_leagues = [England, Spain, Portugal]

ws = Worldsoccer(country_leagues=country_leagues)

for year in range(2000, 2030):
    print(year)
    ws.play_1season(year)
    ws.play_offseason(df_name_list, year)
    
    with open('../../data/pickle/20230111v1_30y.pickle', mode='wb') as f:
        pickle.dump(ws, f)
# Out:
# 2000
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 38/38 [00:10<00:00,  3.46it/s]
# オフシーズン
# ------------------------------
# Premier
#   Brentford
#  所属人数： 16
#  レンタル予定選手： 8
#   AstonVilla
#  所属人数： 18
#  レンタル予定選手： 10
#   Brighton
#  所属人数： 17
#  レンタル予定選手： 9
#   Chelsea
#  所属人数： 17
#  レンタル予定選手： 7
#   CrystalPalace
#  所属人数： 19
#  レンタル予定選手： 6
#   Everton
#  所属人数： 14
#  レンタル予定選手： 11
#   Fulham
#  所属人数： 17
#  レンタル予定選手： 11
#   Leeds
#  所属人数： 14
#  レンタル予定選手： 10
#   Leicester
#  所属人数： 14
#  レンタル予定選手： 10
#   Liverpool
#  所属人数： 14
#  レンタル予定選手： 9
#   ManchesterCity
#  所属人数： 16
#  レンタル予定選手： 11
#   ManchesterUnited
#  所属人数： 19
#  レンタル予定選手： 5
#   Newcastle
#  所属人数： 14
#  レンタル予定選手： 12
#   Nottingham
#  所属人数： 16
#  レンタル予定選手： 9
#   Southampton
#  所属人数： 13
#  レンタル予定選手： 7
#   WestHam
#  所属人数： 12
#  レンタル予定選手： 10
#   Wolverhampton
#  所属人数： 15
#  レンタル予定選手： 12
#   QPR
#  所属人数： 2
#  レンタル予定選手： 22
#   Reading
#  所属人数： 3
#  レンタル予定選手： 23
#   Swansea
#  所属人数： 5
#  レンタル予定選手： 16
# Championship
#   Birmingham
#  所属人数： 24
#  レンタル予定選手： 0
#   Blackburn
#  所属人数： 23
#  レンタル予定選手： 0
#   Bristol
#  所属人数： 25
#  レンタル予定選手： 0
#   Blackpool
#  所属人数： 28
#  レンタル予定選手： 0
#   Coventry
#  所属人数： 24
#  レンタル予定選手： 0
#   Huddersfield
#  所属人数： 23
#  レンタル予定選手： 0
#   HullCity
#  所属人数： 25
#  レンタル予定選手： 0
#   Middlesbrough
#  所属人数： 23
#  レンタル予定選手： 0
#   Millwall
#  所属人数： 22
#  レンタル予定選手： 0
#   Norwich
#  所属人数： 26
#  レンタル予定選手： 0
#   Preston
#  所属人数： 26
#  レンタル予定選手： 0
#   Rotherham
#  所属人数： 22
#  レンタル予定選手： 0
#   ShefieldWednesday
#  所属人数： 22
#  レンタル予定選手： 0
#   Stoke
#  所属人数： 22
#  レンタル予定選手： 0
#   Arsenal
#  所属人数： 22
#  レンタル予定選手： 0
#   Tottenham
#  所属人数： 21
#  レンタル予定選手： 0
#   Bournemouth
#  所属人数： 22
#  レンタル予定選手： 0
#   Accrington
#  所属人数： 23
#  レンタル予定選手： 0
#   Burton
#  所属人数： 22
#  レンタル予定選手： 0
#   Dons
#  所属人数： 24
#  レンタル予定選手： 0
# EFL1
#   SheffieldUnited
#  所属人数： 22
#  レンタル予定選手： 0
#   Sunderland
#  所属人数： 25
#  レンタル予定選手： 0
#   WBA
#  所属人数： 22
#  レンタル予定選手： 0
#   Wigan
#  所属人数： 23
#  レンタル予定選手： 0
#   AFC
#  所属人数： 22
#  レンタル予定選手： 0
#   Chalton
#  所属人数： 25
#  レンタル予定選手： 0
#   Crewe
#  所属人数： 23
#  レンタル予定選手： 0
#   Doncaster
#  所属人数： 25
#  レンタル予定選手： 0
#   Fleetwood
#  所属人数： 24
#  レンタル予定選手： 0
#   Gillingham
#  所属人数： 22
#  レンタル予定選手： 0
#   Ipswitch
#  所属人数： 23
#  レンタル予定選手： 0
#   Lincoln
#  所属人数： 21
#  レンタル予定選手： 0
#   Northampton
#  所属人数： 22
#  レンタル予定選手： 0
#   Oxford
#  所属人数： 28
#  レンタル予定選手： 0
#   Peterborough
#  所属人数： 21
#  レンタル予定選手： 0
#   Plymouth
#  所属人数： 23
#  レンタル予定選手： 0
#   Portsmouth
#  所属人数： 22
#  レンタル予定選手： 0
#   Burnely
#  所属人数： 18
#  レンタル予定選手： 0
#   Cardiff
#  所属人数： 22
#  レンタル予定選手： 0
#   LutonTown
#  所属人数： 19
#  レンタル予定選手： 0
# La Liga Santander
#   RealMadrid
#  所属人数： 13
#  レンタル予定選手： 11
#   Barcelona
#  所属人数： 17
#  レンタル予定選手： 6
#   AtleticoDeMadrid
#  所属人数： 18
#  レンタル予定選手： 8
#   RealSocidad
#  所属人数： 15
#  レンタル予定選手： 9
#   RealBetis
#  所属人数： 16
#  レンタル予定選手： 12
#   AthleticBilbao
#  所属人数： 18
#  レンタル予定選手： 6
#   Sevilla
#  所属人数： 18
#  レンタル予定選手： 10
#   Getafe
#  所属人数： 16
#  レンタル予定選手： 9
#   Celta
#  所属人数： 14
#  レンタル予定選手： 10
#   Osasuna
#  所属人数： 20
#  レンタル予定選手： 4
#   Girona
#  所属人数： 12
#  レンタル予定選手： 13
#   Espanyol
#  所属人数： 15
#  レンタル予定選手： 9
#   Almenia
#  所属人数： 15
#  レンタル予定選手： 9
#   Elche
#  所属人数： 15
#  レンタル予定選手： 9
#   Rayo
#  所属人数： 16
#  レンタル予定選手： 11
#   Cadiz
#  所属人数： 14
#  レンタル予定選手： 12
#   RealValladolid
#  所属人数： 18
#  レンタル予定選手： 6
#   Granada
#  所属人数： 7
#  レンタル予定選手： 16
#   Deporivo
#  所属人数： 7
#  レンタル予定選手： 19
#   Andorra
#  所属人数： 6
#  レンタル予定選手： 17
# La Liga SmartBank
#   Levante
#  所属人数： 22
#  レンタル予定選手： 0
#   Gijon
#  所属人数： 22
#  レンタル予定選手： 0
#   RealZaragoza
#  所属人数： 24
#  レンタル予定選手： 0
#   Eibar
#  所属人数： 27
#  レンタル予定選手： 0
#   Leganes
#  所属人数： 22
#  レンタル予定選手： 0
#   Malaga
#  所属人数： 23
#  レンタル予定選手： 0
#   Huesca
#  所属人数： 24
#  レンタル予定選手： 0
#   Mirandes
#  所属人数： 23
#  レンタル予定選手： 0
#   Albacete
#  所属人数： 21
#  レンタル予定選手： 0
#   Tenerife
#  所属人数： 23
#  レンタル予定選手： 0
#   Ibiza
#  所属人数： 25
#  レンタル予定選手： 0
#   Catagena
#  所属人数： 26
#  レンタル予定選手： 0
#   RacingSantander
#  所属人数： 25
#  レンタル予定選手： 0
#   Burgos
#  所属人数： 23
#  レンタル予定選手： 0
#   Vilarreal
#  所属人数： 20
#  レンタル予定選手： 0
#   Valencia
#  所属人数： 20
#  レンタル予定選手： 0
#   Mallorca
#  所属人数： 20
#  レンタル予定選手： 0
#   Coroba
#  所属人数： 26
#  レンタル予定選手： 0
#   Uniponstas
#  所属人数： 24
#  レンタル予定選手： 0
#   Merida
#  所属人数： 25
#  レンタル予定選手： 1
# Primera Division RFEF
#   Lugo
#  所属人数： 25
#  レンタル予定選手： 0
#   Alcorcon
#  所属人数： 23
#  レンタル予定選手： 0
#   RacingFerrol
#  所属人数： 23
#  レンタル予定選手： 0
#   SanFernando
#  所属人数： 25
#  レンタル予定選手： 0
#   Leonesa
#  所属人数： 19
#  レンタル予定選手： 0
#   Fuenlabrada
#  所属人数： 21
#  レンタル予定選手： 0
#   Algeciras
#  所属人数： 21
#  レンタル予定選手： 0
#   SanSebastian
#  所属人数： 29
#  レンタル予定選手： 0
#   Pontevedra
#  所属人数： 24
#  レンタル予定選手： 0
#   Talavera
#  所属人数： 23
#  レンタル予定選手： 0
#   Ceuta
#  所属人数： 24
#  レンタル予定選手： 0
#   Badajoz
#  所属人数： 19
#  レンタル予定選手： 0
#   LinaresDeportivo
#  所属人数： 21
#  レンタル予定選手： 0
#   Castellon
#  所属人数： 24
#  レンタル予定選手： 0
#   Numancia
#  所属人数： 25
#  レンタル予定選手： 0
#   ReakMurcia
#  所属人数： 22
#  レンタル予定選手： 0
#   Intercity
#  所属人数： 24
#  レンタル予定選手： 0
#   RealOviedo
#  所属人数： 13
#  レンタル予定選手： 0
#   UDLasPalmas
#  所属人数： 17
#  レンタル予定選手： 0
#   Ponferradina
#  所属人数： 15
#  レンタル予定選手： 0
# Liga Portugal
#   Porto
#  所属人数： 26
#  レンタル予定選手： 0
#   SportingCP
#  所属人数： 21
#  レンタル予定選手： 0
#   Braga
#  所属人数： 26
#  レンタル予定選手： 0
#   Guimaraes
#  所属人数： 26
#  レンタル予定選手： 0
#   Vicente
#  所属人数： 23
#  レンタル予定選手： 0
#   Estoril
#  所属人数： 22
#  レンタル予定選手： 0
#   Pacos
#  所属人数： 23
#  レンタル予定選手： 0
#   SantaClara
#  所属人数： 23
#  レンタル予定選手： 0
#   Boavista
#  所属人数： 23
#  レンタル予定選手： 0
#   Portimonense
#  所属人数： 23
#  レンタル予定選手： 1
#   Maritimo
#  所属人数： 22
#  レンタル予定選手： 0
#   CasaPia
#  所属人数： 26
#  レンタル予定選手： 0
#   Vizela
#  所属人数： 24
#  レンタル予定選手： 0
#   RioAve
#  所属人数： 24
#  レンタル予定選手： 1
#   Arouca
#  所属人数： 23
#  レンタル予定選手： 0
#   Chaves
#  所属人数： 23
#  レンタル予定選手： 1
#   AcademicoViseu
#  所属人数： 23
#  レンタル予定選手： 0
#   Vilafranquense
#  所属人数： 18
#  レンタル予定選手： 7
#   BSAD
#  所属人数： 22
#  レンタル予定選手： 1
#   k4sen
#  所属人数： 21
#  レンタル予定選手： 3
# Liga Portugal2
#   Farense
#  所属人数： 26
#  レンタル予定選手： 0
#   Tondeia
#  所属人数： 22
#  レンタル予定選手： 0
#   Mafra
#  所属人数： 22
#  レンタル予定選手： 0
#   Penafiel
#  所属人数： 23
#  レンタル予定選手： 0
#   Uniap Torreense
#  所属人数： 22
#  レンタル予定選手： 0
#   Trofense
#  所属人数： 26
#  レンタル予定選手： 0
#   Nacional
#  所属人数： 22
#  レンタル予定選手： 0
#   Feirense
#  所属人数： 23
#  レンタル予定選手： 0
#   Leixoes
#  所属人数： 28
#  レンタル予定選手： 0
#   EstrelaAmadora
#  所属人数： 23
#  レンタル予定選手： 0
#   Convilha
#  所属人数： 26
#  レンタル予定選手： 0
#   Oliveirense
#  所属人数： 20
#  レンタル予定選手： 0
#   Lisbon
#  所属人数： 23
#  レンタル予定選手： 0
#   Amadora
#  所属人数： 24
#  レンタル予定選手： 0
#   coinbra
#  所属人数： 23
#  レンタル予定選手： 0
#   kerus
#  所属人数： 21
#  レンタル予定選手： 0
#   funcial
#  所属人数： 26
#  レンタル予定選手： 0
#   Benfica
#  所属人数： 18
#  レンタル予定選手： 0
#   Famalicao
#  所属人数： 15
#  レンタル予定選手： 0
#   Moreirense
#  所属人数： 22
#  レンタル予定選手： 0
#  引退人数   　:  277
#  移籍市場人数 :  1218
#
#  移籍市場経過時間 : -2.19秒
#  残留籍市場人数 :  273
#
# 2001
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 38/38 [00:11<00:00,  3.38it/s]
# オフシーズン
# ------------------------------
# Premier
#   Brentford
#  所属人数： 17
#  レンタル予定選手： 16
#   AstonVilla
#  所属人数： 19
#  レンタル予定選手： 19
#   Brighton
#  所属人数： 11
#  レンタル予定選手： 21
#   Chelsea
#  所属人数： 14
#  レンタル予定選手： 18
#   CrystalPalace
#  所属人数： 18
#  レンタル予定選手： 11
#   Everton
#  所属人数： 13
#  レンタル予定選手： 23
#   Fulham
#  所属人数： 17
#  レンタル予定選手： 19
#   Leeds
#  所属人数： 12
#  レンタル予定選手： 23
#   Leicester
#  所属人数： 11
#  レンタル予定選手： 22
#   Liverpool
#  所属人数： 16
#  レンタル予定選手： 18
#   ManchesterCity
#  所属人数： 19
#  レンタル予定選手： 20
#   ManchesterUnited
#  所属人数： 16
#  レンタル予定選手： 16
#   Newcastle
#  所属人数： 12
#  レンタル予定選手： 23
#   Nottingham
#  所属人数： 15
#  レンタル予定選手： 17
#   Southampton
#  所属人数： 12
#  レンタル予定選手： 20
#   WestHam
#  所属人数： 11
#  レンタル予定選手： 23
#   Wolverhampton
#  所属人数： 17
#  レンタル予定選手： 19
#   Norwich
#  所属人数： 3
#  レンタル予定選手： 22
#   Arsenal
#  所属人数： 7
#  レンタル予定選手： 16
#   Tottenham
#  所属人数： 9
#  レンタル予定選手： 16
# Championship
#   Birmingham
#  所属人数： 22
#  レンタル予定選手： 0
#   Blackburn
#  所属人数： 18
#  レンタル予定選手： 0
#   Bristol
#  所属人数： 22
#  レンタル予定選手： 0
#   Coventry
#  所属人数： 26
#  レンタル予定選手： 0
#   Huddersfield
#  所属人数： 22
#  レンタル予定選手： 0
#   HullCity
#  所属人数： 28
#  レンタル予定選手： 0
#   Middlesbrough
#  所属人数： 21
#  レンタル予定選手： 0
#   Millwall
#  所属人数： 18
#  レンタル予定選手： 0
#   Preston
#  所属人数： 28
#  レンタル予定選手： 0
#   Rotherham
#  所属人数： 19
#  レンタル予定選手： 0
#   Stoke
#  所属人数： 18
#  レンタル予定選手： 0
#   Bournemouth
#  所属人数： 18
#  レンタル予定選手： 0
#   Burton
#  所属人数： 18
#  レンタル予定選手： 0
#   Dons
#  所属人数： 19
#  レンタル予定選手： 0
#   QPR
#  所属人数： 47
#  レンタル予定選手： 0
#   Reading
#  所属人数： 47
#  レンタル予定選手： 0
#   Swansea
#  所属人数： 43
#  レンタル予定選手： 0
#   Wigan
#  所属人数： 26
#  レンタル予定選手： 0
#   Gillingham
#  所属人数： 22
#  レンタル予定選手： 0
#   Cardiff
#  所属人数： 23
#  レンタル予定選手： 0
# EFL1
#   SheffieldUnited
#  所属人数： 21
#  レンタル予定選手： 0
#   Sunderland
#  所属人数： 23
#  レンタル予定選手： 0
#   WBA
#  所属人数： 20
#  レンタル予定選手： 0
#   AFC
#  所属人数： 25
#  レンタル予定選手： 0
#   Chalton
#  所属人数： 23
#  レンタル予定選手： 0
#   Crewe
#  所属人数： 22
#  レンタル予定選手： 0
#   Doncaster
#  所属人数： 28
#  レンタル予定選手： 0
#   Fleetwood
#  所属人数： 22
#  レンタル予定選手： 0
#   Ipswitch
#  所属人数： 23
#  レンタル予定選手： 0
#   Lincoln
#  所属人数： 24
#  レンタル予定選手： 0
#   Northampton
#  所属人数： 21
#  レンタル予定選手： 0
#   Oxford
#  所属人数： 23
#  レンタル予定選手： 0
#   Peterborough
#  所属人数： 20
#  レンタル予定選手： 0
#   Plymouth
#  所属人数： 21
#  レンタル予定選手： 0
#   Portsmouth
#  所属人数： 26
#  レンタル予定選手： 0
#   Burnely
#  所属人数： 23
#  レンタル予定選手： 0
#   LutonTown
#  所属人数： 20
#  レンタル予定選手： 0
#   Blackpool
#  所属人数： 14
#  レンタル予定選手： 0
#   ShefieldWednesday
#  所属人数： 11
#  レンタル予定選手： 0
#   Accrington
#  所属人数： 20
#  レンタル予定選手： 0
# La Liga Santander
#   RealMadrid
#  所属人数： 22
#  レンタル予定選手： 11
#   Barcelona
#  所属人数： 27
#  レンタル予定選手： 6
#   AtleticoDeMadrid
#  所属人数： 18
#  レンタル予定選手： 15
#   RealSocidad
#  所属人数： 18
#  レンタル予定選手： 17
#   RealBetis
#  所属人数： 26
#  レンタル予定選手： 12
#   AthleticBilbao
#  所属人数： 22
#  レンタル予定選手： 8
#   Sevilla
#  所属人数： 18
#  レンタル予定選手： 19
#   Getafe
#  所属人数： 20
#  レンタル予定選手： 12
#   Celta
#  所属人数： 25
#  レンタル予定選手： 8
#   Osasuna
#  所属人数： 23
#  レンタル予定選手： 7
#   Girona
#  所属人数： 13
#  レンタル予定選手： 26
#   Espanyol
#  所属人数： 21
#  レンタル予定選手： 10
#   Almenia
#  所属人数： 14
#  レンタル予定選手： 18
#   Elche
#  所属人数： 18
#  レンタル予定選手： 14
#   Rayo
#  所属人数： 16
#  レンタル予定選手： 14
#   RealValladolid
#  所属人数： 21
#  レンタル予定選手： 6
#   Deporivo
#  所属人数： 24
#  レンタル予定選手： 17
#   Gijon
#  所属人数： 4
#  レンタル予定選手： 17
#   Mirandes
#  所属人数： 6
#  レンタル予定選手： 13
#   Catagena
#  所属人数： 5
#  レンタル予定選手： 22
# La Liga SmartBank
#   Levante
#  所属人数： 22
#  レンタル予定選手： 0
#   RealZaragoza
#  所属人数： 23
#  レンタル予定選手： 0
#   Eibar
#  所属人数： 22
#  レンタル予定選手： 0
#   Leganes
#  所属人数： 20
#  レンタル予定選手： 0
#   Malaga
#  所属人数： 27
#  レンタル予定選手： 0
#   Huesca
#  所属人数： 23
#  レンタル予定選手： 0
#   Albacete
#  所属人数： 20
#  レンタル予定選手： 0
#   Ibiza
#  所属人数： 20
#  レンタル予定選手： 0
#   RacingSantander
#  所属人数： 25
#  レンタル予定選手： 0
#   Burgos
#  所属人数： 22
#  レンタル予定選手： 0
#   Vilarreal
#  所属人数： 23
#  レンタル予定選手： 0
#   Valencia
#  所属人数： 17
#  レンタル予定選手： 0
#   Mallorca
#  所属人数： 18
#  レンタル予定選手： 0
#   Uniponstas
#  所属人数： 20
#  レンタル予定選手： 0
#   Cadiz
#  所属人数： 30
#  レンタル予定選手： 0
#   Granada
#  所属人数： 33
#  レンタル予定選手： 0
#   Andorra
#  所属人数： 42
#  レンタル予定選手： 0
#   Lugo
#  所属人数： 23
#  レンタル予定選手： 0
#   Alcorcon
#  所属人数： 24
#  レンタル予定選手： 1
#   Numancia
#  所属人数： 25
#  レンタル予定選手： 0
# Primera Division RFEF
#   RacingFerrol
#  所属人数： 23
#  レンタル予定選手： 0
#   SanFernando
#  所属人数： 25
#  レンタル予定選手： 0
#   Leonesa
#  所属人数： 24
#  レンタル予定選手： 0
#   Fuenlabrada
#  所属人数： 28
#  レンタル予定選手： 0
#   Algeciras
#  所属人数： 27
#  レンタル予定選手： 0
#   SanSebastian
#  所属人数： 24
#  レンタル予定選手： 0
#   Pontevedra
#  所属人数： 27
#  レンタル予定選手： 0
#   Talavera
#  所属人数： 28
#  レンタル予定選手： 0
#   Ceuta
#  所属人数： 25
#  レンタル予定選手： 0
#   Badajoz
#  所属人数： 20
#  レンタル予定選手： 0
#   LinaresDeportivo
#  所属人数： 22
#  レンタル予定選手： 0
#   Castellon
#  所属人数： 22
#  レンタル予定選手： 0
#   ReakMurcia
#  所属人数： 21
#  レンタル予定選手： 0
#   Intercity
#  所属人数： 23
#  レンタル予定選手： 0
#   RealOviedo
#  所属人数： 15
#  レンタル予定選手： 0
#   UDLasPalmas
#  所属人数： 20
#  レンタル予定選手： 0
#   Ponferradina
#  所属人数： 23
#  レンタル予定選手： 0
#   Tenerife
#  所属人数： 20
#  レンタル予定選手： 0
#   Coroba
#  所属人数： 20
#  レンタル予定選手： 0
#   Merida
#  所属人数： 21
#  レンタル予定選手： 0
# Liga Portugal
#   Porto
#  所属人数： 21
#  レンタル予定選手： 1
#   SportingCP
#  所属人数： 26
#  レンタル予定選手： 0
#   Braga
#  所属人数： 24
#  レンタル予定選手： 1
#   Guimaraes
#  所属人数： 27
#  レンタル予定選手： 0
#   Estoril
#  所属人数： 18
#  レンタル予定選手： 3
#   Pacos
#  所属人数： 23
#  レンタル予定選手： 2
#   SantaClara
#  所属人数： 22
#  レンタル予定選手： 1
#   Portimonense
#  所属人数： 20
#  レンタル予定選手： 1
#   Maritimo
#  所属人数： 22
#  レンタル予定選手： 3
#   CasaPia
#  所属人数： 28
#  レンタル予定選手： 2
#   Vizela
#  所属人数： 27
#  レンタル予定選手： 2
#   RioAve
#  所属人数： 25
#  レンタル予定選手： 2
#   Arouca
#  所属人数： 27
#  レンタル予定選手： 2
#   Chaves
#  所属人数： 24
#  レンタル予定選手： 2
#   AcademicoViseu
#  所属人数： 23
#  レンタル予定選手： 0
#   Vilafranquense
#  所属人数： 25
#  レンタル予定選手： 5
#   k4sen
#  所属人数： 20
#  レンタル予定選手： 4
#   Tondeia
#  所属人数： 13
#  レンタル予定選手： 5
#   Lisbon
#  所属人数： 22
#  レンタル予定選手： 3
#   Famalicao
#  所属人数： 18
#  レンタル予定選手： 1
# Liga Portugal2
#   Farense
#  所属人数： 25
#  レンタル予定選手： 0
#   Mafra
#  所属人数： 22
#  レンタル予定選手： 0
#   Penafiel
#  所属人数： 26
#  レンタル予定選手： 0
#   Uniap Torreense
#  所属人数： 24
#  レンタル予定選手： 0
#   Trofense
#  所属人数： 22
#  レンタル予定選手： 0
#   Nacional
#  所属人数： 24
#  レンタル予定選手： 0
#   Feirense
#  所属人数： 23
#  レンタル予定選手： 0
#   Leixoes
#  所属人数： 26
#  レンタル予定選手： 0
#   EstrelaAmadora
#  所属人数： 26
#  レンタル予定選手： 0
#   Convilha
#  所属人数： 23
#  レンタル予定選手： 0
#   Oliveirense
#  所属人数： 25
#  レンタル予定選手： 0
#   Amadora
#  所属人数： 20
#  レンタル予定選手： 0
#   coinbra
#  所属人数： 27
#  レンタル予定選手： 0
#   kerus
#  所属人数： 24
#  レンタル予定選手： 0
#   funcial
#  所属人数： 26
#  レンタル予定選手： 0
#   Benfica
#  所属人数： 22
#  レンタル予定選手： 0
#   Moreirense
#  所属人数： 24
#  レンタル予定選手： 0
#   Vicente
#  所属人数： 14
#  レンタル予定選手： 0
#   Boavista
#  所属人数： 14
#  レンタル予定選手： 0
#   BSAD
#  所属人数： 23
#  レンタル予定選手： 0
#  引退人数   　:  234
#  移籍市場人数 :  1604
#
#  移籍市場経過時間 : -3.26秒
#  残留籍市場人数 :  434
#
# 2002
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 38/38 [00:11<00:00,  3.26it/s]
# オフシーズン
# ------------------------------
# Premier
#   Brentford
#  所属人数： 15
#  レンタル予定選手： 25
#   AstonVilla
#  所属人数： 12
#  レンタル予定選手： 26
#   Brighton
#  所属人数： 15
#  レンタル予定選手： 28
#   CrystalPalace
#  所属人数： 16
#  レンタル予定選手： 18
#   Everton
#  所属人数： 13
#  レンタル予定選手： 27
#   Fulham
#  所属人数： 15
#  レンタル予定選手： 24
#   Leeds
#  所属人数： 16
#  レンタル予定選手： 28
#   Leicester
#  所属人数： 20
#  レンタル予定選手： 24
#   Liverpool
#  所属人数： 10
#  レンタル予定選手： 29
#   ManchesterCity
#  所属人数： 17
#  レンタル予定選手： 23
#   ManchesterUnited
#  所属人数： 13
#  レンタル予定選手： 24
#   Newcastle
#  所属人数： 13
#  レンタル予定選手： 33
#   Nottingham
#  所属人数： 13
#  レンタル予定選手： 27
#   Southampton
#  所属人数： 9
#  レンタル予定選手： 34
#   WestHam
#  所属人数： 11
#  レンタル予定選手： 34
#   Wolverhampton
#  所属人数： 15
#  レンタル予定選手： 25
#   Tottenham
#  所属人数： 11
#  レンタル予定選手： 28
#   Coventry
#  所属人数： 6
#  レンタル予定選手： 15
#   Bournemouth
#  所属人数： 9
#  レンタル予定選手： 13
#   Swansea
#  所属人数： 4
#  レンタル予定選手： 33
# Championship
#   Birmingham
#  所属人数： 20
#  レンタル予定選手： 0
#   Blackburn
#  所属人数： 21
#  レンタル予定選手： 0
#   Bristol
#  所属人数： 20
#  レンタル予定選手： 0
#   Huddersfield
#  所属人数： 20
#  レンタル予定選手： 0
#   Middlesbrough
#  所属人数： 20
#  レンタル予定選手： 0
#   Millwall
#  所属人数： 24
#  レンタル予定選手： 1
#   Preston
#  所属人数： 22
#  レンタル予定選手： 0
#   Rotherham
#  所属人数： 19
#  レンタル予定選手： 0
#   Stoke
#  所属人数： 18
#  レンタル予定選手： 0
#   Burton
#  所属人数： 17
#  レンタル予定選手： 0
#   Dons
#  所属人数： 17
#  レンタル予定選手： 0
#   QPR
#  所属人数： 38
#  レンタル予定選手： 0
#   Reading
#  所属人数： 43
#  レンタル予定選手： 0
#   Gillingham
#  所属人数： 16
#  レンタル予定選手： 0
#   Chelsea
#  所属人数： 38
#  レンタル予定選手： 0
#   Norwich
#  所属人数： 45
#  レンタル予定選手： 0
#   Arsenal
#  所属人数： 37
#  レンタル予定選手： 0
#   Chalton
#  所属人数： 20
#  レンタル予定選手： 0
#   Northampton
#  所属人数： 14
#  レンタル予定選手： 0
#   Accrington
#  所属人数： 18
#  レンタル予定選手： 0
# EFL1
#   SheffieldUnited
#  所属人数： 20
#  レンタル予定選手： 0
#   Sunderland
#  所属人数： 21
#  レンタル予定選手： 0
#   WBA
#  所属人数： 19
#  レンタル予定選手： 0
#   AFC
#  所属人数： 21
#  レンタル予定選手： 0
#   Crewe
#  所属人数： 22
#  レンタル予定選手： 0
#   Doncaster
#  所属人数： 22
#  レンタル予定選手： 0
#   Fleetwood
#  所属人数： 16
#  レンタル予定選手： 0
#   Ipswitch
#  所属人数： 14
#  レンタル予定選手： 0
#   Lincoln
#  所属人数： 23
#  レンタル予定選手： 0
#   Oxford
#  所属人数： 21
#  レンタル予定選手： 0
#   Peterborough
#  所属人数： 17
#  レンタル予定選手： 0
#   Plymouth
#  所属人数： 18
#  レンタル予定選手： 0
#   Portsmouth
#  所属人数： 18
#  レンタル予定選手： 0
#   Burnely
#  所属人数： 15
#  レンタル予定選手： 0
#   LutonTown
#  所属人数： 15
#  レンタル予定選手： 0
#   Blackpool
#  所属人数： 16
#  レンタル予定選手： 0
#   ShefieldWednesday
#  所属人数： 16
#  レンタル予定選手： 0
#   HullCity
#  所属人数： 14
#  レンタル予定選手： 0
#   Wigan
#  所属人数： 15
#  レンタル予定選手： 0
#   Cardiff
#  所属人数： 15
#  レンタル予定選手： 0
# La Liga Santander
#   RealMadrid
#  所属人数： 18
#  レンタル予定選手： 12
#   Barcelona
#  所属人数： 20
#  レンタル予定選手： 10
#   AtleticoDeMadrid
#  所属人数： 17
#  レンタル予定選手： 21
#   RealSocidad
#  所属人数： 15
#  レンタル予定選手： 23
#   RealBetis
#  所属人数： 19
#  レンタル予定選手： 15
#   AthleticBilbao
#  所属人数： 21
#  レンタル予定選手： 8
#   Sevilla
#  所属人数： 18
#  レンタル予定選手： 24
#   Getafe
#  所属人数： 14
#  レンタル予定選手： 16
#   Celta
#  所属人数： 22
#  レンタル予定選手： 10
#   Osasuna
#  所属人数： 21
#  レンタル予定選手： 11
#   Girona
#  所属人数： 11
#  レンタル予定選手： 40
#   Espanyol
#  所属人数： 16
#  レンタル予定選手： 15
#   Almenia
#  所属人数： 13
#  レンタル予定選手： 27
#   Elche
#  所属人数： 16
#  レンタル予定選手： 22
#   Rayo
#  所属人数： 12
#  レンタル予定選手： 23
#   RealValladolid
#  所属人数： 17
#  レンタル予定選手： 11
#   Deporivo
#  所属人数： 10
#  レンタル予定選手： 19
#   Levante
#  所属人数： 8
#  レンタル予定選手： 12
#   Mallorca
#  所属人数： 9
#  レンタル予定選手： 14
#   Granada
#  所属人数： 9
#  レンタル予定選手： 13
# La Liga SmartBank
#   RealZaragoza
#  所属人数： 23
#  レンタル予定選手： 0
#   Eibar
#  所属人数： 18
#  レンタル予定選手： 0
#   Malaga
#  所属人数： 26
#  レンタル予定選手： 0
#   Albacete
#  所属人数： 18
#  レンタル予定選手： 0
#   Ibiza
#  所属人数： 17
#  レンタル予定選手： 0
#   RacingSantander
#  所属人数： 20
#  レンタル予定選手： 0
#   Burgos
#  所属人数： 22
#  レンタル予定選手： 0
#   Vilarreal
#  所属人数： 23
#  レンタル予定選手： 0
#   Valencia
#  所属人数： 18
#  レンタル予定選手： 0
#   Uniponstas
#  所属人数： 19
#  レンタル予定選手： 0
#   Cadiz
#  所属人数： 26
#  レンタル予定選手： 0
#   Andorra
#  所属人数： 35
#  レンタル予定選手： 0
#   Lugo
#  所属人数： 18
#  レンタル予定選手： 0
#   Numancia
#  所属人数： 17
#  レンタル予定選手： 0
#   Gijon
#  所属人数： 39
#  レンタル予定選手： 0
#   Mirandes
#  所属人数： 32
#  レンタル予定選手： 0
#   Catagena
#  所属人数： 44
#  レンタル予定選手： 0
#   Badajoz
#  所属人数： 18
#  レンタル予定選手： 0
#   LinaresDeportivo
#  所属人数： 20
#  レンタル予定選手： 0
#   RealOviedo
#  所属人数： 20
#  レンタル予定選手： 0
# Primera Division RFEF
#   RacingFerrol
#  所属人数： 16
#  レンタル予定選手： 0
#   SanFernando
#  所属人数： 19
#  レンタル予定選手： 0
#   Leonesa
#  所属人数： 21
#  レンタル予定選手： 0
#   Fuenlabrada
#  所属人数： 19
#  レンタル予定選手： 0
#   Algeciras
#  所属人数： 16
#  レンタル予定選手： 0
#   SanSebastian
#  所属人数： 13
#  レンタル予定選手： 0
#   Pontevedra
#  所属人数： 22
#  レンタル予定選手： 0
#   Talavera
#  所属人数： 20
#  レンタル予定選手： 0
#   Ceuta
#  所属人数： 20
#  レンタル予定選手： 0
#   Castellon
#  所属人数： 19
#  レンタル予定選手： 0
#   ReakMurcia
#  所属人数： 16
#  レンタル予定選手： 0
#   Intercity
#  所属人数： 18
#  レンタル予定選手： 0
#   UDLasPalmas
#  所属人数： 18
#  レンタル予定選手： 0
#   Ponferradina
#  所属人数： 18
#  レンタル予定選手： 0
#   Tenerife
#  所属人数： 19
#  レンタル予定選手： 0
#   Coroba
#  所属人数： 16
#  レンタル予定選手： 0
#   Merida
#  所属人数： 16
#  レンタル予定選手： 0
#   Leganes
#  所属人数： 11
#  レンタル予定選手： 0
#   Huesca
#  所属人数： 12
#  レンタル予定選手： 0
#   Alcorcon
#  所属人数： 17
#  レンタル予定選手： 0
# Liga Portugal
#   Porto
#  所属人数： 17
#  レンタル予定選手： 1
#   SportingCP
#  所属人数： 25
#  レンタル予定選手： 0
#   Braga
#  所属人数： 20
#  レンタル予定選手： 2
#   Guimaraes
#  所属人数： 24
#  レンタル予定選手： 1
#   Estoril
#  所属人数： 24
#  レンタル予定選手： 3
#   Pacos
#  所属人数： 23
#  レンタル予定選手： 2
#   SantaClara
#  所属人数： 22
#  レンタル予定選手： 0
#   Portimonense
#  所属人数： 18
#  レンタル予定選手： 2
#   Maritimo
#  所属人数： 18
#  レンタル予定選手： 3
#   CasaPia
#  所属人数： 22
#  レンタル予定選手： 3
#   Vizela
#  所属人数： 27
#  レンタル予定選手： 2
#   RioAve
#  所属人数： 23
#  レンタル予定選手： 2
#   Arouca
#  所属人数： 27
#  レンタル予定選手： 2
#   Chaves
#  所属人数： 29
#  レンタル予定選手： 1
#   AcademicoViseu
#  所属人数： 25
#  レンタル予定選手： 0
#   k4sen
#  所属人数： 27
#  レンタル予定選手： 2
#   Famalicao
#  所属人数： 20
#  レンタル予定選手： 1
#   Uniap Torreense
#  所属人数： 15
#  レンタル予定選手： 2
#   funcial
#  所属人数： 24
#  レンタル予定選手： 1
#   Boavista
#  所属人数： 17
#  レンタル予定選手： 2
# Liga Portugal2
#   Farense
#  所属人数： 25
#  レンタル予定選手： 0
#   Mafra
#  所属人数： 20
#  レンタル予定選手： 0
#   Penafiel
#  所属人数： 13
#  レンタル予定選手： 0
#   Trofense
#  所属人数： 18
#  レンタル予定選手： 0
#   Nacional
#  所属人数： 22
#  レンタル予定選手： 0
#   Feirense
#  所属人数： 23
#  レンタル予定選手： 0
#   Leixoes
#  所属人数： 20
#  レンタル予定選手： 0
#   EstrelaAmadora
#  所属人数： 18
#  レンタル予定選手： 0
#   Convilha
#  所属人数： 22
#  レンタル予定選手： 0
#   Oliveirense
#  所属人数： 24
#  レンタル予定選手： 0
#   Amadora
#  所属人数： 19
#  レンタル予定選手： 0
#   coinbra
#  所属人数： 23
#  レンタル予定選手： 0
#   kerus
#  所属人数： 22
#  レンタル予定選手： 0
#   Benfica
#  所属人数： 19
#  レンタル予定選手： 0
#   Moreirense
#  所属人数： 19
#  レンタル予定選手： 0
#   Vicente
#  所属人数： 14
#  レンタル予定選手： 0
#   BSAD
#  所属人数： 15
#  レンタル予定選手： 0
#   Vilafranquense
#  所属人数： 20
#  レンタル予定選手： 0
#   Tondeia
#  所属人数： 13
#  レンタル予定選手： 0
#   Lisbon
#  所属人数： 22
#  レンタル予定選手： 0
#  引退人数   　:  358
#  移籍市場人数 :  2301
#
#  移籍市場経過時間 : -4.17秒
#  残留籍市場人数 :  608
#
# 2003
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 38/38 [00:11<00:00,  3.19it/s]
# オフシーズン
# ------------------------------
# Premier
#   Brentford
#  所属人数： 12
#  レンタル予定選手： 34
#   AstonVilla
#  所属人数： 9
#  レンタル予定選手： 32
#   Brighton
#  所属人数： 8
#  レンタル予定選手： 35
#   CrystalPalace
#  所属人数： 10
#  レンタル予定選手： 26
#   Everton
#  所属人数： 13
#  レンタル予定選手： 30
#   Fulham
#  所属人数： 13
#  レンタル予定選手： 27
#   Leeds
#  所属人数： 14
#  レンタル予定選手： 32
#   Leicester
#  所属人数： 17
#  レンタル予定選手： 20
#   Liverpool
#  所属人数： 11
#  レンタル予定選手： 36
#   ManchesterCity
#  所属人数： 12
#  レンタル予定選手： 31
#   ManchesterUnited
#  所属人数： 12
#  レンタル予定選手： 33
#   Newcastle
#  所属人数： 14
#  レンタル予定選手： 37
#   Nottingham
#  所属人数： 12
#  レンタル予定選手： 37
#   WestHam
#  所属人数： 6
#  レンタル予定選手： 45
#   Wolverhampton
#  所属人数： 8
#  レンタル予定選手： 36
#   Tottenham
#  所属人数： 12
#  レンタル予定選手： 35
#   Bournemouth
#  所属人数： 12
#  レンタル予定選手： 23
#   Preston
#  所属人数： 7
#  レンタル予定選手： 13
#   Burton
#  所属人数： 6
#  レンタル予定選手： 16
#   Accrington
#  所属人数： 4
#  レンタル予定選手： 10
# Championship
#   Birmingham
#  所属人数： 18
#  レンタル予定選手： 0
#   Blackburn
#  所属人数： 21
#  レンタル予定選手： 0
#   Bristol
#  所属人数： 18
#  レンタル予定選手： 0
#   Huddersfield
#  所属人数： 18
#  レンタル予定選手： 0
#   Middlesbrough
#  所属人数： 24
#  レンタル予定選手： 0
#   Millwall
#  所属人数： 25
#  レンタル予定選手： 0
#   Rotherham
#  所属人数： 22
#  レンタル予定選手： 0
#   Stoke
#  所属人数： 20
#  レンタル予定選手： 0
#   QPR
#  所属人数： 31
#  レンタル予定選手： 0
#   Reading
#  所属人数： 33
#  レンタル予定選手： 0
#   Gillingham
#  所属人数： 12
#  レンタル予定選手： 0
#   Chelsea
#  所属人数： 32
#  レンタル予定選手： 0
#   Norwich
#  所属人数： 39
#  レンタル予定選手： 0
#   Arsenal
#  所属人数： 37
#  レンタル予定選手： 0
#   Southampton
#  所属人数： 47
#  レンタル予定選手： 0
#   Coventry
#  所属人数： 35
#  レンタル予定選手： 0
#   Swansea
#  所属人数： 50
#  レンタル予定選手： 0
#   Crewe
#  所属人数： 18
#  レンタル予定選手： 0
#   Blackpool
#  所属人数： 15
#  レンタル予定選手： 0
#   Wigan
#  所属人数： 18
#  レンタル予定選手： 0
# EFL1
#   SheffieldUnited
#  所属人数： 19
#  レンタル予定選手： 0
#   Sunderland
#  所属人数： 20
#  レンタル予定選手： 0
#   WBA
#  所属人数： 18
#  レンタル予定選手： 0
#   AFC
#  所属人数： 14
#  レンタル予定選手： 0
#   Doncaster
#  所属人数： 15
#  レンタル予定選手： 0
#   Fleetwood
#  所属人数： 21
#  レンタル予定選手： 0
#   Ipswitch
#  所属人数： 20
#  レンタル予定選手： 0
#   Lincoln
#  所属人数： 17
#  レンタル予定選手： 0
#   Oxford
#  所属人数： 23
#  レンタル予定選手： 0
#   Peterborough
#  所属人数： 19
#  レンタル予定選手： 0
#   Plymouth
#  所属人数： 17
#  レンタル予定選手： 0
#   Portsmouth
#  所属人数： 15
#  レンタル予定選手： 0
#   Burnely
#  所属人数： 13
#  レンタル予定選手： 0
#   LutonTown
#  所属人数： 18
#  レンタル予定選手： 0
#   ShefieldWednesday
#  所属人数： 18
#  レンタル予定選手： 0
#   HullCity
#  所属人数： 22
#  レンタル予定選手： 0
#   Cardiff
#  所属人数： 15
#  レンタル予定選手： 0
#   Dons
#  所属人数： 11
#  レンタル予定選手： 0
#   Chalton
#  所属人数： 16
#  レンタル予定選手： 0
#   Northampton
#  所属人数： 16
#  レンタル予定選手： 0
# La Liga Santander
#   RealMadrid
#  所属人数： 22
#  レンタル予定選手： 13
#   Barcelona
#  所属人数： 21
#  レンタル予定選手： 9
#   AtleticoDeMadrid
#  所属人数： 21
#  レンタル予定選手： 20
#   RealSocidad
#  所属人数： 16
#  レンタル予定選手： 24
#   RealBetis
#  所属人数： 21
#  レンタル予定選手： 16
#   AthleticBilbao
#  所属人数： 16
#  レンタル予定選手： 12
#   Getafe
#  所属人数： 20
#  レンタル予定選手： 18
#   Celta
#  所属人数： 23
#  レンタル予定選手： 11
#   Osasuna
#  所属人数： 17
#  レンタル予定選手： 13
#   Girona
#  所属人数： 19
#  レンタル予定選手： 34
#   Espanyol
#  所属人数： 18
#  レンタル予定選手： 15
#   Elche
#  所属人数： 19
#  レンタル予定選手： 19
#   Rayo
#  所属人数： 21
#  レンタル予定選手： 23
#   RealValladolid
#  所属人数： 15
#  レンタル予定選手： 13
#   Deporivo
#  所属人数： 17
#  レンタル予定選手： 18
#   Levante
#  所属人数： 17
#  レンタル予定選手： 13
#   Granada
#  所属人数： 19
#  レンタル予定選手： 11
#   Malaga
#  所属人数： 4
#  レンタル予定選手： 13
#   Ibiza
#  所属人数： 7
#  レンタル予定選手： 13
#   Catagena
#  所属人数： 5
#  レンタル予定選手： 33
# La Liga SmartBank
#   RealZaragoza
#  所属人数： 18
#  レンタル予定選手： 0
#   Eibar
#  所属人数： 14
#  レンタル予定選手： 0
#   Albacete
#  所属人数： 19
#  レンタル予定選手： 0
#   RacingSantander
#  所属人数： 20
#  レンタル予定選手： 0
#   Burgos
#  所属人数： 17
#  レンタル予定選手： 0
#   Vilarreal
#  所属人数： 21
#  レンタル予定選手： 0
#   Valencia
#  所属人数： 16
#  レンタル予定選手： 0
#   Uniponstas
#  所属人数： 21
#  レンタル予定選手： 0
#   Cadiz
#  所属人数： 16
#  レンタル予定選手： 0
#   Andorra
#  所属人数： 31
#  レンタル予定選手： 0
#   Lugo
#  所属人数： 16
#  レンタル予定選手： 0
#   Numancia
#  所属人数： 18
#  レンタル予定選手： 0
#   Mirandes
#  所属人数： 27
#  レンタル予定選手： 0
#   Badajoz
#  所属人数： 18
#  レンタル予定選手： 0
#   Sevilla
#  所属人数： 37
#  レンタル予定選手： 0
#   Almenia
#  所属人数： 38
#  レンタル予定選手： 0
#   Mallorca
#  所属人数： 33
#  レンタル予定選手： 0
#   Pontevedra
#  所属人数： 20
#  レンタル予定選手： 0
#   Leganes
#  所属人数： 9
#  レンタル予定選手： 0
#   Huesca
#  所属人数： 16
#  レンタル予定選手： 0
# Primera Division RFEF
#   RacingFerrol
#  所属人数： 13
#  レンタル予定選手： 0
#   SanFernando
#  所属人数： 15
#  レンタル予定選手： 0
#   Leonesa
#  所属人数： 12
#  レンタル予定選手： 0
#   Fuenlabrada
#  所属人数： 14
#  レンタル予定選手： 0
#   Algeciras
#  所属人数： 18
#  レンタル予定選手： 0
#   SanSebastian
#  所属人数： 14
#  レンタル予定選手： 0
#   Talavera
#  所属人数： 13
#  レンタル予定選手： 0
#   Ceuta
#  所属人数： 18
#  レンタル予定選手： 0
#   Castellon
#  所属人数： 12
#  レンタル予定選手： 0
#   ReakMurcia
#  所属人数： 13
#  レンタル予定選手： 0
#   Intercity
#  所属人数： 11
#  レンタル予定選手： 0
#   UDLasPalmas
#  所属人数： 19
#  レンタル予定選手： 0
#   Ponferradina
#  所属人数： 14
#  レンタル予定選手： 0
#   Tenerife
#  所属人数： 16
#  レンタル予定選手： 0
#   Coroba
#  所属人数： 20
#  レンタル予定選手： 0
#   Merida
#  所属人数： 15
#  レンタル予定選手： 0
#   Alcorcon
#  所属人数： 16
#  レンタル予定選手： 0
#   Gijon
#  所属人数： 25
#  レンタル予定選手： 0
#   LinaresDeportivo
#  所属人数： 8
#  レンタル予定選手： 0
#   RealOviedo
#  所属人数： 16
#  レンタル予定選手： 0
# Liga Portugal
#   Porto
#  所属人数： 19
#  レンタル予定選手： 1
#   SportingCP
#  所属人数： 22
#  レンタル予定選手： 2
#   Braga
#  所属人数： 21
#  レンタル予定選手： 1
#   Guimaraes
#  所属人数： 19
#  レンタル予定選手： 1
#   Estoril
#  所属人数： 20
#  レンタル予定選手： 0
#   Pacos
#  所属人数： 17
#  レンタル予定選手： 3
#   Portimonense
#  所属人数： 19
#  レンタル予定選手： 0
#   Maritimo
#  所属人数： 20
#  レンタル予定選手： 0
#   CasaPia
#  所属人数： 22
#  レンタル予定選手： 1
#   Vizela
#  所属人数： 22
#  レンタル予定選手： 1
#   RioAve
#  所属人数： 19
#  レンタル予定選手： 0
#   Arouca
#  所属人数： 14
#  レンタル予定選手： 1
#   Chaves
#  所属人数： 23
#  レンタル予定選手： 1
#   AcademicoViseu
#  所属人数： 20
#  レンタル予定選手： 1
#   k4sen
#  所属人数： 19
#  レンタル予定選手： 0
#   Famalicao
#  所属人数： 19
#  レンタル予定選手： 0
#   funcial
#  所属人数： 15
#  レンタル予定選手： 1
#   Convilha
#  所属人数： 18
#  レンタル予定選手： 1
#   Amadora
#  所属人数： 16
#  レンタル予定選手： 2
#   Moreirense
#  所属人数： 16
#  レンタル予定選手： 1
# Liga Portugal2
#   Farense
#  所属人数： 19
#  レンタル予定選手： 0
#   Mafra
#  所属人数： 14
#  レンタル予定選手： 0
#   Penafiel
#  所属人数： 18
#  レンタル予定選手： 0
#   Trofense
#  所属人数： 19
#  レンタル予定選手： 0
#   Nacional
#  所属人数： 19
#  レンタル予定選手： 0
#   Feirense
#  所属人数： 20
#  レンタル予定選手： 0
#   Leixoes
#  所属人数： 19
#  レンタル予定選手： 0
#   EstrelaAmadora
#  所属人数： 23
#  レンタル予定選手： 0
#   Oliveirense
#  所属人数： 16
#  レンタル予定選手： 0
#   coinbra
#  所属人数： 21
#  レンタル予定選手： 0
#   kerus
#  所属人数： 14
#  レンタル予定選手： 0
#   Benfica
#  所属人数： 22
#  レンタル予定選手： 0
#   Vicente
#  所属人数： 18
#  レンタル予定選手： 0
#   BSAD
#  所属人数： 14
#  レンタル予定選手： 0
#   Vilafranquense
#  所属人数： 19
#  レンタル予定選手： 0
#   Tondeia
#  所属人数： 18
#  レンタル予定選手： 0
#   Lisbon
#  所属人数： 18
#  レンタル予定選手： 0
#   SantaClara
#  所属人数： 16
#  レンタル予定選手： 0
#   Uniap Torreense
#  所属人数： 15
#  レンタル予定選手： 0
#   Boavista
#  所属人数： 17
#  レンタル予定選手： 0
#  引退人数   　:  288
#  移籍市場人数 :  2765
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [9], line 8
#       6 print(year)
#       7 ws.play_1season(year)
# ----> 8 ws.play_offseason(df_name_list, year)
#      10 with open('../../data/pickle/20230111v1_30y.pickle', mode='wb') as f:
#      11     pickle.dump(ws, f)
#
# File ~/program/game/football/notebook/run_and_show/../../src/worldsoccer.py:238, in play_offseason(self, df_name_list, year)
#     236 for p in out_players:
#     237     p.contract = 0
# --> 238 self.free_players.extend(out_players)
#     239 t.affilation_players = [p for p in t.affilation_players if p not in out_players]
#     241 if count<1:
#     242     # メンバー外の若手をレンタルに
#
# File ~/program/game/football/notebook/run_and_show/../../src/object/team.py:199, in Team.get_free_players(self, free_players, league)
#     197 for pos in self.empty_position.keys():
#     198     num = self.empty_position[pos]
# --> 199     new_players = [p for p in free_players if p.main_position in POSITION_LOW_DICT[pos] and p.main_rate>=league.min_rate and p.main_rate<=league.max_rate]
#     200     new_players = sorted(new_players, key=lambda x:x.main_rate, reverse=True)
#     201     if len(new_players) >= num:
#
# File ~/program/game/football/notebook/run_and_show/../../src/object/team.py:199, in <listcomp>(.0)
#     197 for pos in self.empty_position.keys():
#     198     num = self.empty_position[pos]
# --> 199     new_players = [p for p in free_players if p.main_position in POSITION_LOW_DICT[pos] and p.main_rate>=league.min_rate and p.main_rate<=league.max_rate]
#     200     new_players = sorted(new_players, key=lambda x:x.main_rate, reverse=True)
#     201     if len(new_players) >= num:
#
# KeyboardInterrupt:

# %% [markdown]
# for year in range(2030,  2050):
#     print(year)
#     ws.play_1season(year)
#     ws.play_offseason(df_name_list, year)

# %%
with open('../../data/pickle/20221122v1_30y.pickle', mode='rb') as f:
    ws = pickle.load(f)

# %%
for year in range(2026, 2030):
    print(year)
    ws.play_1season(year)
    ws.play_offseason(df_name_list, year)
    
    with open('../../data/pickle/20221122v1_30y.pickle', mode='wb') as f:
        pickle.dump(ws, f)

# %%
with open('../../data/pickle/20221113v2_50y.pickle', mode='wb') as f:
    pickle.dump(ws, f)

# %%
ws.players_result
