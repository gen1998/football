# %%
import numpy as np
import pandas as pd
import math

pd.set_option('display.max_rows', 80)

import random
import pickle

import time

import sys
sys.path.append("../../")

from src.object import *
from src.create import *
from src.print_result import *

from config.formation import *
from config.config import *

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "last_expr"

# %%
with open('../../data/pickle/20221011v3_10y.pickle', mode='rb') as f:
    England = pickle.load(f)

# %%
all_member = pd.DataFrame()
for l in England.leagues:
    for t in l.teams:
        for p in t.affilation_players:
            buff = pd.DataFrame(np.array([[p.name, t.name, l.name, p.uuid, p.age, p.born_year, p.main_position, p.main_rate, p.grow_type, p.pace, p.shooting, p.passing, p.dribbling, p.defending, p.physicality, "現役"]]), 
                                columns = ["名前", "チーム", "リーグ", "uuid", "年齢", "生まれ年", "ポジション", "Rate", "成長タイプ", "pac", "sho", "pas", "dri", "def", "phy", "進退"])
            all_member = pd.concat([all_member, buff])
for p in England.retire_players:
    buff = pd.DataFrame(np.array([[p.name, t.name, l.name, p.uuid, p.age, p.born_year, p.main_position, p.main_rate, p.grow_type, p.pace, p.shooting, p.passing, p.dribbling, p.defending, p.physicality, "引退"]]), 
                        columns = ["名前", "チーム", "リーグ", "uuid", "年齢", "生まれ年", "ポジション", "Rate", "成長タイプ","pac", "sho", "pas", "dri", "def", "phy", "進退"])
    all_member = pd.concat([all_member, buff])

for p in England.free_players:
    buff = pd.DataFrame(np.array([[p.name, t.name, l.name, p.uuid, p.age, p.born_year, p.main_position, p.main_rate,  p.grow_type, p.pace, p.shooting, p.passing, p.dribbling, p.defending, p.physicality, "フリー"]]), 
                        columns = ["名前", "チーム", "リーグ", "uuid", "年齢", "生まれ年", "ポジション", "Rate", "成長タイプ","pac", "sho", "pas", "dri", "def", "phy", "進退"])
    all_member = pd.concat([all_member, buff])
all_member = all_member.reset_index(drop=True)

# %% [markdown]
# # 結果一覧

# %% [markdown]
# ## リーグ・カップ戦結果

# %%
print("チーム一覧")
print()
league_num = 0
print(England.leagues[league_num].name)
print([[i, t.name] for i, t in enumerate(England.leagues[league_num].teams)])

print()
league_num = 1
print(England.leagues[league_num].name)
print([[i, t.name] for i, t in enumerate(England.leagues[league_num].teams)])

print()
league_num = 2
print(England.leagues[league_num].name)
print([[i, t.name] for i, t in enumerate(England.leagues[league_num].teams)])

display(England.leagues[0].champion)
display(England.leagues[1].champion)
display(England.leagues[2].champion)

display(England.competition_result_top)
# Out:
# チーム一覧
#
# premier
# [[0, 'Birmingham'], [1, 'Liverpool'], [2, 'Dublin'], [3, 'Nottingham'], [4, 'Dundee'], [5, 'Motherwell'], [6, 'Vienna'], [7, 'Sunderland'], [8, 'Gentilly'], [9, 'Paris'], [10, 'Colombes'], [11, 'Paisley'], [12, 'Newark'], [13, 'Swansea'], [14, 'Blackburn'], [15, 'Portsmouth'], [16, 'Shrewsbury'], [17, 'Arnhem'], [18, 'Bristol'], [19, 'Brussels']]
#
# championship
# [[0, 'Wrexham'], [1, 'Kilmarnock'], [2, 'Rotterdam'], [3, 'Newcastle'], [4, 'Antwerp'], [5, 'Basel'], [6, 'London'], [7, 'Belfast'], [8, 'Edinburgh'], [9, 'Karlsruhe'], [10, 'Glasgow'], [11, 'Crewe'], [12, 'Manchester'], [13, 'Viña del Mar'], [14, 'Aberdeen'], [15, 'Richmond'], [16, 'Stoke-on-Trent'], [17, 'Gothenburg'], [18, 'Buenos Aires'], [19, 'Bangor']]
#
# EFL
# [[0, 'Prague'], [1, 'Haarlem'], [2, 'Kristiania'], [3, 'The Hague'], [4, 'Budapest'], [5, 'Aberdare'], [6, 'Montevideo'], [7, 'Southampton'], [8, 'Llandudno'], [9, 'Middlesbrough'], [10, 'Cardiff'], [11, 'Bradford'], [12, 'Saint-Cloud'], [13, 'Duisburg'], [14, 'Greenock'], [15, 'Sheffield'], [16, 'Geneva'], [17, 'Wolverhampton'], [18, 'Milan'], [19, 'Derby']]
#                           優勝                            得点王
# premier_2000         Paisley        Gerard(Paisley)  /  21点
# premier_2001         Paisley        Ivin(Blackburn)  /  18点
# premier_2002          Bangor  Gerren(Wolverhampton)  /  20点
# premier_2003       Sheffield         Jaegar(Bangor)  /  24点
# premier_2004       Sheffield  Jonanthony(Sheffield)  /  27点
# premier_2005      Nottingham     Lyndon(Nottingham)  /  25点
# premier_2006      Nottingham         Eligha(London)  /  31点
# premier_2007      Nottingham         Eligha(London)  /  27点
# premier_2008        Aberdeen         Ido(Newcastle)  /  34点
# premier_2009       Newcastle       Eligha(Aberdeen)  /  35点
# premier_2010        Aberdeen       Lyndon(Aberdeen)  /  38点
# premier_2011       Edinburgh       Jebediah(Bangor)  /  35点
# premier_2012       Edinburgh     Refugio(Edinburgh)  /  34点
# premier_2013          Dublin      Eligha(Sheffield)  /  31点
# premier_2014          Dublin          Kylar(Dublin)  /  40点
# premier_2015          Dublin          Kylar(Dublin)  /  38点
# premier_2016  Stoke-on-Trent          Kylar(Dublin)  /  37点
# premier_2017  Stoke-on-Trent    Tai(Stoke-on-Trent)  /  26点
# premier_2018       Liverpool     Refugio(Liverpool)  /  37点
# premier_2019       Liverpool      Jaydis(Liverpool)  /  29点
# premier_2020       Liverpool       Kylar(Liverpool)  /  38点
# premier_2021       Liverpool       Kylar(Liverpool)  /  36点
# premier_2022          Dublin        Kylar(Aberdeen)  /  37点
# premier_2023          Dundee        Refugio(Dundee)  /  30点
# premier_2024        Brussels          Ramon(Dundee)  /  32点
# premier_2025        Colombes       Tavaughn(Dublin)  /  26点
# premier_2026      Sunderland    Shirley(Sunderland)  /  28点
# premier_2027      Sunderland     Deacon(Sunderland)  /  37点
# premier_2028      Birmingham        Art(Birmingham)  /  34点
# premier_2029          Vienna      Sebastien(Vienna)  /  32点
#                            優勝                           得点王
# championship_2000   Llandudno  Vanessa(Southampton)  /  19点
# championship_2001    Budapest       Kenden(Bristol)  /  27点
# championship_2002  Nottingham       Kenden(Bristol)  /  22点
# championship_2003    Greenock      Caedan(Greenock)  /  28点
# EFL_2023       Greenock          Verlin(Basel)  /  33点
# EFL_2024        Bristol           Osie(Geneva)  /  37点
# EFL_2025       Greenock           Osie(Geneva)  /  34点
# EFL_2026   Viña del Mar    Mccoy(Viña del Mar)  /  33点
# EFL_2027         Geneva           Osie(Geneva)  /  38点
# EFL_2028          Derby     Jameson(Llandudno)  /  36点
# EFL_2029   Buenos Aires   Lattie(Buenos Aires)  /  29点
#             年度                       優勝                      準優勝  \
# FA杯_2000  2000          Newark(premier)         Glasgow(premier)
# FA杯_2001  2001          Bangor(premier)      Sunderland(premier)
# FA杯_2002  2002       Sheffield(premier)         Swansea(premier)
# FA杯_2003  2003      Birmingham(premier)   Wolverhampton(premier)
# FA杯_2004  2004         Paisley(premier)      Sunderland(premier)
# FA杯_2005  2005         Bristol(premier)      Manchester(premier)
# FA杯_2006  2006          London(premier)  Stoke-on-Trent(premier)
# FA杯_2007  2007       Sheffield(premier)       Newcastle(premier)
# FA杯_2008  2008          Bangor(premier)       Newcastle(premier)
# FA杯_2009  2009       Newcastle(premier)       Edinburgh(premier)
# FA杯_2010  2010       Newcastle(premier)          Bangor(premier)
# FA杯_2011  2011       Blackburn(premier)  Stoke-on-Trent(premier)
# FA杯_2012  2012       Blackburn(premier)       Sheffield(premier)
# FA杯_2013  2013       Edinburgh(premier)       Sheffield(premier)
# FA杯_2014  2014          Dublin(premier)       Edinburgh(premier)
# FA杯_2015  2015          Newark(premier)       Blackburn(premier)
# FA杯_2016  2016       Liverpool(premier)          Arnhem(premier)
# FA杯_2017  2017  Stoke-on-Trent(premier)          Dublin(premier)
# FA杯_2018  2018  Stoke-on-Trent(premier)       Liverpool(premier)
# FA杯_2019  2019       Liverpool(premier)          Dublin(premier)
# FA杯_2020  2020       Liverpool(premier)         Antwerp(premier)
# FA杯_2021  2021       Liverpool(premier)      Birmingham(premier)
# FA杯_2022  2022        Gentilly(premier)          Dublin(premier)
# FA杯_2023  2023        Aberdeen(premier)      Nottingham(premier)
# FA杯_2024  2024        Aberdeen(premier)          Dundee(premier)
# FA杯_2025  2025        Colombes(premier)        Brussels(premier)
# FA杯_2026  2026      Sunderland(premier)      Birmingham(premier)
# FA杯_2027  2027      Sunderland(premier)        Aberdeen(premier)
# FA杯_2028  2028      Motherwell(premier)   Brussels(championship)
# FA杯_2029  2029      Sunderland(premier)      Birmingham(premier)
#
#                                               得点王
# FA杯_2000            Elmer(Newark(premier))  /  7点
# FA杯_2001          Addison(Bangor(premier))  /  9点
# FA杯_2002          Joniel(Swansea(premier))  /  9点
# FA杯_2003     Kenry(Wolverhampton(premier))  /  9点
# FA杯_2004         Connell(Glasgow(premier))  /  5点
# FA杯_2005      Lyndon(Nottingham(premier))  /  10点
# FA杯_2006  Alondre(Stoke-on-Trent(premier))  /  9点
# FA杯_2007        Earlie(Sheffield(premier))  /  9点
# FA杯_2008         Jebediah(Bangor(premier))  /  9点
# FA杯_2009           Ido(Newcastle(premier))  /  9点
# FA杯_2010             Idan(Vienna(premier))  /  7点
# FA杯_2011       Nolberto(Aberdeen(premier))  /  8点
# FA杯_2012        Eligha(Sheffield(premier))  /  6点
# FA杯_2013        Eligha(Sheffield(premier))  /  8点
# FA杯_2014           Kylar(Dublin(premier))  /  11点
# FA杯_2015      Refugio(Edinburgh(premier))  /  10点
# FA杯_2016            Kylar(Dublin(premier))  /  9点
# FA杯_2017           Kylar(Dublin(premier))  /  11点
# FA杯_2018             Van(Vienna(premier))  /  11点
# FA杯_2019       Refugio(Liverpool(premier))  /  9点
# FA杯_2020          Jacobe(Belfast(premier))  /  6点
# FA杯_2021       Tavaughn(Richmond(premier))  /  7点
# FA杯_2022          Kylar(Aberdeen(premier))  /  7点
# FA杯_2023        Theopolis(Dundee(premier))  /  8点
# FA杯_2024           Lyal(Brussels(premier))  /  6点
# FA杯_2025         Tavaughn(Dublin(premier))  /  6点
# FA杯_2026         Tkai(Birmingham(premier))  /  6点
# FA杯_2027      Deacon(Sunderland(premier))  /  10点
# FA杯_2028          Tai(Birmingham(premier))  /  6点
# FA杯_2029       Worth(Sunderland(premier))  /  10点

# %% [markdown]
# ## チームごとの結果

# %%
league_num = 0
team_num = 11
year = 2026

print(England.leagues[league_num].teams[team_num].name)
b = England.leagues[league_num].teams[team_num].competition_result
display(pd.DataFrame(b.values(), index=b.keys(), columns=["ラウンド"]))
display(England.leagues[league_num].teams[team_num].result)

output = England.players_result
output = output[output["チーム"]==England.leagues[league_num].teams[team_num].name]
output = output[output["分類"]=="リーグ"]
display(output.groupby("uuid").sum()[["試合数", "goal", "assist", "CS"]].sort_values("試合数", ascending=False).head(40))
# Out:
# Paisley
#           ラウンド
# FA杯_2000  ベスト4
# FA杯_2001   3回戦
# FA杯_2002   3回戦
# FA杯_2003  ベスト8
# FA杯_2004    優勝
# FA杯_2005   3回戦
# FA杯_2006   1回戦
# FA杯_2007   3回戦
# FA杯_2008   1回戦
# FA杯_2009   3回戦
# FA杯_2010   3回戦
# FA杯_2011   2回戦
# FA杯_2012   1回戦
# FA杯_2013  ベスト8
# FA杯_2014   2回戦
# FA杯_2015   2回戦
# FA杯_2016   1回戦
# FA杯_2017   2回戦
# FA杯_2018   1回戦
# FA杯_2019   1回戦
# FA杯_2020   2回戦
# FA杯_2021   1回戦
# FA杯_2022   1回戦
# FA杯_2023   2回戦
# FA杯_2024   1回戦
# FA杯_2025  ベスト8
# FA杯_2026   1回戦
# FA杯_2027   2回戦
# FA杯_2028   1回戦
# FA杯_2029   1回戦
#                   win lose row   得点   失点 得失点差 Points   順位          リーグ名
# premier_2000       24    5   9   61   26   35     81   1位       premier
# premier_2001       22    3  13   59   20   39     79   1位       premier
# premier_2002       19    7  12   45   18   27     69   5位       premier
# premier_2003       19   12   7   51   34   17     64   8位       premier
# premier_2004       18    7  13   60   30   30     67   6位       premier
# premier_2005       23    9   6   54   30   24     75   3位       premier
# premier_2006       10   21   7   37   50  -13     37  17位       premier
# 3350   Collin  6f11364c-48c0-11ed-a79d-00155d14f69a  27    79    1    LW
# 6661   Collin  6f11364c-48c0-11ed-a79d-00155d14f69a  28    79    0    RW
# 9970   Collin  6f11364c-48c0-11ed-a79d-00155d14f69a  29    79    1    LW
# 13274  Collin  6f11364c-48c0-11ed-a79d-00155d14f69a  30    79    0    LW
# 16606  Collin  6f11364c-48c0-11ed-a79d-00155d14f69a  31    79    2    LW
# 19891  Collin  6f11364c-48c0-11ed-a79d-00155d14f69a  32    78    1    RW
# 23989  Collin  6f11364c-48c0-11ed-a79d-00155d14f69a  33    77    0    RW
# 28105  Collin  6f11364c-48c0-11ed-a79d-00155d14f69a  34    74    1    RW
# 29818  Collin  6f11364c-48c0-11ed-a79d-00155d14f69a  35    72    0    RW
# 33173  Collin  6f11364c-48c0-11ed-a79d-00155d14f69a  36    69    0    LW
#
#                  リーグ    年度          チーム     レンタル元       分類    順位  試合数  goal  \
# 65     rental_league  2000  rental_team   Paisley  レンタルリーグ  記録なし   40     0
# 3350   rental_league  2001  rental_team   Paisley  レンタルリーグ  記録なし   40     0
# 6661   rental_league  2002  rental_team   Paisley  レンタルリーグ  記録なし   40     0
# 9970   rental_league  2003  rental_team   Paisley  レンタルリーグ  記録なし   40     0
# 13274  rental_league  2004  rental_team   Paisley  レンタルリーグ  記録なし   40     0
# 16606  rental_league  2005  rental_team   Bristol  レンタルリーグ  記録なし   40     0
# 19891  rental_league  2006  rental_team   Bristol  レンタルリーグ  記録なし   40     0
# 23989        premier  2007      Bristol                リーグ   15位    8     0
# 28105   championship  2008       Arnhem                リーグ    2位   22    10
# 29818  rental_league  2009  rental_team    Arnhem  レンタルリーグ  記録なし   40     0
# 33173  rental_league  2010  rental_team  Richmond  レンタルリーグ  記録なし   40     0
#
#        assist  CS  怪我欠場 賞
# 65          0   0     0
# 3350        0   0     0
# 6661        0   0     0
# 9970        0   0     0
# 13274       0   0     0
# 16606       0   0     0
# 19891       0   0     0
# 23989       0   1    13
# 28105       5   2     3
# 29818       0   0     0
# 33173       0   0     0

# %% [markdown]
# ## 年ごとの結果

# %%
year = 2026
league_num = 0
league_name = f"{England.leagues[league_num].name}_{year}"
competition_name = f"FA杯_{year}"
England.leagues[league_num].team_result[league_name]
England.competition_result[competition_name]

# %%
output = England.players_result
output.sort_values("Rate", ascending=False).head(30)

# %%
all_member.sort_values("年齢", ascending=False).head(30)

# %%
all_member[all_member["成長タイプ"]=="legend"]

# %% [markdown]
# ## 全選手成績

# %%
output = England.players_result
#output = output[output["チーム"]==England.leagues[league_num].teams[team_num].name]
#output = output[output["分類"]=="リーグ"]
output.groupby("uuid").sum()[["試合数", "goal", "assist", "CS", "怪我欠場"]].sort_values("試合数", ascending=False).head(10)

# %%
uuid_ = "1e203c00-48b7-11ed-b2b6-00155d14f69a"
print_player(England, all_member, uuid_)

# %% [markdown]
# ## データ保存

# %%
with open('../data/pickle/20221011v2_30y.pickle', mode='wb') as f:
    pickle.dump(England, f)
