# %%
import numpy as np
import pandas as pd
import math

pd.set_option('display.max_rows', 80)

import random

import time

import sys
sys.path.append("../")

from src.object import *
from src.create import *
from src.print_result import *

from config.formation import *
from config.config import *

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "last_expr"

# %%
df_name = pd.read_csv("../data/csv/NationalNames.csv")
df_name_list = list(df_name[df_name.Gender=='M'].Name.sample(1000))

# %%
df_place = pd.read_csv("../data/csv/results.csv")
df_place = df_place.city.unique()
df_place_count = 0

# %%
league_team = []

for i in range(20):
    mean_rate = np.random.normal(68, 1)
    Cp = Create_player(position_num={"ST":4, "RW":2, "CAM":3, "RM":2, "CM":5, "CDM":3, "CB":4, "RB":4, "GK":3}, 
                       min_rate=50, max_rate=100, 
                       age_mean=27,
                       mean_rate=mean_rate,
                       now_year=2000,
                       df_name_list=df_name_list)
    Cp.create_teams()
    players = Cp.players
    formation = random_create_formation()
    A = Team(name=df_place[df_place_count], 
             formation=formation,
             min_rate=0,#これたぶんいらない
             max_rate=100)#これもいらない
    A.affilation_players = players
    
    league_team.append(A)
    df_place_count += 1

L1 = League(name="premier", 
            teams=league_team,
            num=20,
            min_rate=75,
            max_rate=99,
            mean_rate=67,
            category='top',
            relegation_num=3)

# %%
league_team = []

for i in range(20):
    mean_rate = np.random.normal(63, 1)
    Cp = Create_player(position_num={"ST":4, "RW":2, "CAM":3, "RM":2, "CM":5, "CDM":3, "CB":4, "RB":4, "GK":3}, 
                       min_rate=50, max_rate=78, 
                       age_mean=26,
                       mean_rate=mean_rate,
                       now_year=2000,
                       df_name_list=df_name_list)
    Cp.create_teams()
    players = Cp.players
    formation = random_create_formation()
    A = Team(name=df_place[df_place_count], 
             formation=formation,
             min_rate=0,
             max_rate=100)
    A.affilation_players = players
    
    league_team.append(A)
    df_place_count += 1

L2 = League(name="championship",
            teams=league_team,
            num=20,
            min_rate=60,
            max_rate=78,
            mean_rate=62,
            category='middle',
            relegation_num=3,
            promotion_num=3)

# %%
league_team = []

for i in range(20):
    mean_rate = np.random.normal(58, 1)
    Cp = Create_player(position_num={"ST":4, "RW":2, "CAM":3, "RM":2, "CM":5, "CDM":3, "CB":4, "RB":4, "GK":3}, 
                       min_rate=47, max_rate=73, 
                       age_mean=25,
                       mean_rate=mean_rate,
                       now_year=2000,
                       df_name_list=df_name_list)
    Cp.create_teams()
    players = Cp.players
    formation = random_create_formation()
    A = Team(name=df_place[df_place_count], 
             formation=formation,
             min_rate=0,
             max_rate=100)
    A.affilation_players = players
    
    league_team.append(A)
    df_place_count += 1

L3 = League(name="EFL",
            teams=league_team,
            num=20,
            min_rate=47,
            max_rate=73,
            mean_rate=58,
            category='lowest',
            relegation_num=0,
            promotion_num=3)

# %%
England = ProSoccerLeague(name="england", leagues=[L1, L2, L3])

for year in range(2000,  2030):
    print(year)
    competition = Competition(name=f"FA杯_{year}")

    England.play_1season(year, competition)
    England.play_offseason(df_name_list, year)
# Out:
# 2000
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 38/38 [00:56<00:00,  1.48s/it]
# 2001
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 38/38 [00:45<00:00,  1.21s/it]
# 2002
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 38/38 [00:42<00:00,  1.12s/it]
# 2003
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 38/38 [00:45<00:00,  1.21s/it]
# 2004
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 38/38 [00:41<00:00,  1.09s/it]
# 2005
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 38/38 [00:54<00:00,  1.44s/it]
# 2006
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 38/38 [00:41<00:00,  1.09s/it]
# 2007
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 38/38 [00:41<00:00,  1.09s/it]
# 2008
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 38/38 [00:42<00:00,  1.13s/it]
# 2009
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 38/38 [00:45<00:00,  1.21s/it]
# 2010
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 38/38 [00:47<00:00,  1.24s/it]
# 2011
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 38/38 [00:46<00:00,  1.23s/it]
# 2012
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 38/38 [00:47<00:00,  1.26s/it]
# 2013
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 38/38 [00:46<00:00,  1.22s/it]
# 2014
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 38/38 [00:46<00:00,  1.22s/it]
# 2015
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 38/38 [00:46<00:00,  1.22s/it]
# 2016
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 38/38 [00:46<00:00,  1.23s/it]
# 2017
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 38/38 [00:47<00:00,  1.25s/it]
# 2018
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 38/38 [00:48<00:00,  1.28s/it]
# 2019
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 38/38 [00:47<00:00,  1.24s/it]
# 2020
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 38/38 [00:57<00:00,  1.52s/it]
# 2021
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 38/38 [00:54<00:00,  1.42s/it]
# 2022
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 38/38 [00:54<00:00,  1.42s/it]
# 2023
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 38/38 [00:55<00:00,  1.45s/it]
# 2024
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 38/38 [00:54<00:00,  1.43s/it]
# 2025
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 38/38 [00:55<00:00,  1.47s/it]
# 2026
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 38/38 [00:57<00:00,  1.50s/it]
# 2027
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 38/38 [00:57<00:00,  1.53s/it]
# 2028
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 38/38 [00:58<00:00,  1.53s/it]
# 2029
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 38/38 [00:58<00:00,  1.54s/it]

# %% [markdown]
# for year in range(2030,  2040):
#     print(year)
#     competition = Competition(name=f"FA杯_{year}")
#
#     England.play_1season(year, competition)
#     England.play_offseason(df_name_list, year)

# %%
#England = ProSoccerLeague(name="england", leagues=[L1, L2, L3])
all_member = pd.DataFrame()
for l in England.leagues:
    for t in l.teams:
        for p in t.affilation_players:
            buff = pd.DataFrame(np.array([[p.name, t.name, l.name, p.uuid, p.age, p.born_year, p.main_position, p.main_rate, p.grow_type, p.pace, p.shooting, p.passing, p.dribbling, p.defending, p.physicality, "現役"]]), 
                                columns = ["名前", "チーム", "リーグ", "uuid", "年齢", "生まれ年", "ポジション", "Rate", "成長タイプ", "pac", "sho", "pas", "dri", "def", "phy", "進退"])
            all_member = pd.concat([all_member, buff])
for p in England.retire_players:
    buff = pd.DataFrame(np.array([[p.name, t.name, l.name, p.uuid, p.age, p.born_year, p.main_position, p.main_rate, p.grow_type, p.pace, p.shooting, p.passing, p.dribbling, p.defending, p.physicality, "引退"]]), 
                        columns = ["名前", "チーム", "リーグ", "uuid", "年齢", "生まれ年", "ポジション", "Rate", "成長タイプ","pac", "sho", "pas", "dri", "def", "phy", "進退"])
    all_member = pd.concat([all_member, buff])

for p in England.free_players:
    buff = pd.DataFrame(np.array([[p.name, t.name, l.name, p.uuid, p.age, p.born_year, p.main_position, p.main_rate,  p.grow_type, p.pace, p.shooting, p.passing, p.dribbling, p.defending, p.physicality, "フリー"]]), 
                        columns = ["名前", "チーム", "リーグ", "uuid", "年齢", "生まれ年", "ポジション", "Rate", "成長タイプ","pac", "sho", "pas", "dri", "def", "phy", "進退"])
    all_member = pd.concat([all_member, buff])
all_member = all_member.reset_index(drop=True)

# %% [markdown]
# # 結果一覧

# %% [markdown]
# ## リーグ・カップ戦結果

# %%
print("チーム一覧")
print()
league_num = 0
print(England.leagues[league_num].name)
print([[i, t.name] for i, t in enumerate(England.leagues[league_num].teams)])

print()
league_num = 1
print(England.leagues[league_num].name)
print([[i, t.name] for i, t in enumerate(England.leagues[league_num].teams)])

print()
league_num = 2
print(England.leagues[league_num].name)
print([[i, t.name] for i, t in enumerate(England.leagues[league_num].teams)])

display(England.leagues[0].champion)
display(England.leagues[1].champion)
display(England.leagues[2].champion)

display(England.competition_result_top)
# Out:
# チーム一覧
#
# premier
# [[0, 'Newark'], [1, 'Budapest'], [2, 'Paris'], [3, 'Portsmouth'], [4, 'Geneva'], [5, 'Bangor'], [6, 'Vienna'], [7, 'Crewe'], [8, 'Glasgow'], [9, 'Stoke-on-Trent'], [10, 'Edinburgh'], [11, 'Llandudno'], [12, 'Southampton'], [13, 'Dundee'], [14, 'Sunderland'], [15, 'Gothenburg'], [16, 'Paisley'], [17, 'Newcastle'], [18, 'Nottingham'], [19, 'Sheffield']]
#
# championship
# [[0, 'The Hague'], [1, 'Buenos Aires'], [2, 'Dublin'], [3, 'Richmond'], [4, 'Aberdare'], [5, 'Saint-Cloud'], [6, 'Belfast'], [7, 'Manchester'], [8, 'Haarlem'], [9, 'Birmingham'], [10, 'Swansea'], [11, 'Shrewsbury'], [12, 'Greenock'], [13, 'Blackburn'], [14, 'Liverpool'], [15, 'Duisburg'], [16, 'Montevideo'], [17, 'Rotterdam'], [18, 'Prague'], [19, 'Bristol']]
#
# EFL
# [[0, 'Bradford'], [1, 'Kilmarnock'], [2, 'Colombes'], [3, 'Karlsruhe'], [4, 'London'], [5, 'Antwerp'], [6, 'Aberdeen'], [7, 'Kristiania'], [8, 'Gentilly'], [9, 'Wrexham'], [10, 'Arnhem'], [11, 'Derby'], [12, 'Basel'], [13, 'Viña del Mar'], [14, 'Cardiff'], [15, 'Milan'], [16, 'Motherwell'], [17, 'Brussels'], [18, 'Middlesbrough'], [19, 'Wolverhampton']]
#                           優勝                              得点王
# premier_2000       Sheffield           Amiel(Wrexham)  /  21点
# premier_2001         Glasgow          Raheen(Glasgow)  /  22点
# premier_2002          Newark              Luz(Newark)  /  23点
# premier_2003           Crewe       Bob(Wolverhampton)  /  25点
# premier_2004          Newark           Eulalio(Crewe)  /  43点
# premier_2005  Stoke-on-Trent  Eulalio(Stoke-on-Trent)  /  29点
# premier_2006  Stoke-on-Trent           Jaseph(London)  /  32点
# premier_2007          London          Abraham(London)  /  29点
# premier_2008         Glasgow          Ellison(Newark)  /  30点
# premier_2009       Newcastle          Sixto(Brussels)  /  29点
# premier_2010         Wrexham          Tobe(Edinburgh)  /  37点
# premier_2011        Brussels            Bob(Brussels)  /  31点
# premier_2012        Brussels            Toby(Bristol)  /  27点
# premier_2013       Edinburgh         Anshuman(Dundee)  /  32点
# premier_2014       Edinburgh          Toby(Edinburgh)  /  26点
# premier_2015         Haarlem           Irven(Haarlem)  /  33点
# premier_2016           Paris      Millard(Shrewsbury)  /  22点
# premier_2017     Southampton           Irven(Haarlem)  /  33点
# premier_2018     Southampton     Millard(Southampton)  /  37点
# premier_2019      Nottingham        Terrance(Haarlem)  /  24点
# premier_2020      Nottingham        Javonn(Liverpool)  /  21点
# premier_2021         Paisley       Millard(Liverpool)  /  24点
# premier_2022      Portsmouth         Parthiv(Haarlem)  /  18点
# premier_2023       Liverpool      Augustus(Liverpool)  /  26点
# premier_2024          Vienna            Colt(Paisley)  /  24点
# premier_2025         Glasgow          Jaffer(Glasgow)  /  38点
# premier_2026         Glasgow          Jaffer(Glasgow)  /  36点
# premier_2027           Crewe           Zerrick(Crewe)  /  32点
# premier_2028          Newark          Zerrick(Newark)  /  43点
# premier_2029  Stoke-on-Trent   Mercer(Stoke-on-Trent)  /  44点
#                              優勝                            得点王
# championship_2000        Vienna    Altin(Buenos Aires)  /  19点
# championship_2001         Paris    Eustacio(Newcastle)  /  25点
# championship_2002  Buenos Aires       Yi(Buenos Aires)  /  24点
# championship_2003    Montevideo           Ilia(Vienna)  /  26点
# championship_2004        Dundee       Hinton(Aberdare)  /  23点
# championship_2005    Montevideo     Renzo(Southampton)  /  23点
# championship_2006      Aberdeen      Marvin(Llandudno)  /  25点
# championship_2007    Motherwell     Eustacio(Budapest)  /  28点
# championship_2008       Cardiff    Marvin(Saint-Cloud)  /  21点
# championship_2009    Birmingham    Caeleb(Southampton)  /  26点
# championship_2010    Nottingham        Griffith(Paris)  /  25点
# championship_2011    Manchester       Presley(Haarlem)  /  26点
# championship_2012         Paris     Vlad(Buenos Aires)  /  24点
# championship_2013       Haarlem        Basil(Aberdare)  /  28点
# championship_2014       Paisley       Parthiv(Swansea)  /  25点
# championship_2015      Duisburg     Keisuke(The Hague)  /  32点
# championship_2016   Southampton        Jorel(Greenock)  /  24点
# championship_2017      Duisburg       Edric(The Hague)  /  25点
# championship_2018      Greenock      Sincere(Greenock)  /  25点
# championship_2019     Rotterdam        Valgene(Dublin)  /  26点
# championship_2020       Swansea        Valgene(Dublin)  /  18点
# championship_2021         Crewe       Hulon(Llandudno)  /  25点
# championship_2022       Glasgow  Bracken(Buenos Aires)  /  26点
# championship_2023      Brussels     Mamie(Saint-Cloud)  /  33点
# championship_2024       Glasgow       Augusten(Prague)  /  28点
# championship_2025     Edinburgh        Edric(Aberdare)  /  23点
# championship_2026     Llandudno         Tip(Llandudno)  /  30点
# championship_2027      Greenock          Pavel(Dundee)  /  22点
# championship_2028    Gothenburg      Sahir(Gothenburg)  /  30点
# championship_2029     Newcastle        Raif(Newcastle)  /  29点
#                       優勝                             得点王
# EFL_2000     Saint-Cloud     Delano(Saint-Cloud)  /  27点
# EFL_2001    Viña del Mar        Irish(Rotterdam)  /  25点
# EFL_2002        Aberdare         Hanley(Antwerp)  /  23点
# EFL_2003       Liverpool      Valdemar(Gentilly)  /  22点
# EFL_2004     Saint-Cloud           Dondi(Arnhem)  /  29点
# EFL_2005        Greenock        Sherwood(Prague)  /  27点
# EFL_2006           Derby        Sherwood(Prague)  /  32点
# EFL_2007        Greenock        Raimundo(Geneva)  /  24点
# EFL_2008      Portsmouth       Emory(Kristiania)  /  30点
# EFL_2009       Karlsruhe       Codey(Kilmarnock)  /  30点
# EFL_2010       Sheffield    Jahan(Middlesbrough)  /  29点
# EFL_2011       Karlsruhe       Saabir(Llandudno)  /  31点
# EFL_2012        Greenock        Ezra(Kristiania)  /  23点
# EFL_2013      Portsmouth         Tip(Montevideo)  /  25点
# EFL_2014       Sheffield      Clydell(Blackburn)  /  28点
# EFL_2015      Gothenburg         Everett(Arnhem)  /  33点
# EFL_2016      Kristiania           Alban(Arnhem)  /  29点
# EFL_2017  Stoke-on-Trent    Sherwood(Manchester)  /  30点
# EFL_2018      Sunderland         Bevin(Colombes)  /  34点
# EFL_2019          Arnhem            Abrar(Derby)  /  24点
# EFL_2020         Belfast       Kenley(Blackburn)  /  31点
# EFL_2021   Wolverhampton       Nathanal(Antwerp)  /  29点
# EFL_2022         Cardiff       Sonya(Kilmarnock)  /  23点
# EFL_2023       Rotterdam       Lonnie(Karlsruhe)  /  32点
# EFL_2024      Manchester          Jemario(Derby)  /  31点
# EFL_2025       Blackburn      Erasmo(Motherwell)  /  29点
# EFL_2026         Cardiff  Demetrious(Manchester)  /  31点
# EFL_2027       Sheffield        Harve(Karlsruhe)  /  31点
# EFL_2028   Middlesbrough   Winton(Wolverhampton)  /  29点
# EFL_2029         Bristol          Mose(Bradford)  /  26点
#             年度                       優勝                      準優勝  \
# FA杯_2000  2000         Paisley(premier)         Glasgow(premier)
# FA杯_2001  2001         Glasgow(premier)       Edinburgh(premier)
# FA杯_2002  2002          Newark(premier)      Shrewsbury(premier)
# FA杯_2003  2003         Glasgow(premier)         Swansea(premier)
# FA杯_2004  2004   Wolverhampton(premier)          London(premier)
# FA杯_2005  2005        Richmond(premier)          London(premier)
# FA杯_2006  2006  Stoke-on-Trent(premier)           Crewe(premier)
# FA杯_2007  2007  Stoke-on-Trent(premier)          London(premier)
# FA杯_2008  2008  Stoke-on-Trent(premier)        Brussels(premier)
# FA杯_2009  2009         Glasgow(premier)        Brussels(premier)
# FA杯_2010  2010         Wrexham(premier)          Newark(premier)
# FA杯_2011  2011       Edinburgh(premier)        Brussels(premier)
# FA杯_2012  2012        Brussels(premier)      Nottingham(premier)
# FA杯_2013  2013        Budapest(premier)      Nottingham(premier)
# FA杯_2014  2014        Budapest(premier)      Shrewsbury(premier)
# FA杯_2015  2015         Haarlem(premier)       Liverpool(premier)
# FA杯_2016  2016         Bristol(premier)         Haarlem(premier)
# FA杯_2017  2017     Southampton(premier)        Budapest(premier)
# FA杯_2018  2018         Haarlem(premier)         Paisley(premier)
# FA杯_2019  2019     Southampton(premier)         Bristol(premier)
# FA杯_2020  2020       Edinburgh(premier)         Bristol(premier)
# FA杯_2021  2021      Birmingham(premier)     Southampton(premier)
# FA杯_2022  2022       Liverpool(premier)     Southampton(premier)
# FA杯_2023  2023       Liverpool(premier)        Duisburg(premier)
# FA杯_2024  2024       Liverpool(premier)          Geneva(premier)
# FA杯_2025  2025       Liverpool(premier)         Paisley(premier)
# FA杯_2026  2026         Glasgow(premier)          Bangor(premier)
# FA杯_2027  2027           Crewe(premier)  Stoke-on-Trent(premier)
# FA杯_2028  2028          Newark(premier)           Paris(premier)
# FA杯_2029  2029  Stoke-on-Trent(premier)       Llandudno(premier)
#
#                                                得点王
# FA杯_2000        Regginald(Glasgow(premier))  /  8点
# FA杯_2001        Darris(Sunderland(premier))  /  7点
# FA杯_2002            Amiel(Wrexham(premier))  /  5点
# FA杯_2003           Walton(Swansea(premier))  /  9点
# FA杯_2004          Jovante(Wrexham(premier))  /  5点
# FA杯_2005            Jaseph(London(premier))  /  7点
# FA杯_2006             Simmie(Crewe(premier))  /  9点
# FA杯_2007           Abraham(London(premier))  /  9点
# FA杯_2008    Darris(Stoke-on-Trent(premier))  /  7点
# FA杯_2009            Alban(Glasgow(premier))  /  9点
# FA杯_2010         Arnold(Blackburn(premier))  /  7点
# FA杯_2011             Bob(Brussels(premier))  /  8点
# FA杯_2012          Olivia(Brussels(premier))  /  8点
# FA杯_2013            Tobe(Budapest(premier))  /  9点
# FA杯_2014     Jacquan(Cardiff(championship))  /  5点
# FA杯_2015         Burnis(Liverpool(premier))  /  7点
# FA杯_2016           Javonn(Bristol(premier))  /  8点
# FA杯_2017          Brook(Edinburgh(premier))  /  6点
# FA杯_2018         Terrance(Haarlem(premier))  /  7点
# FA杯_2019      Millard(Southampton(premier))  /  6点
# FA杯_2020            Laurin(Newark(premier))  /  5点
# FA杯_2021         Javonn(Liverpool(premier))  /  7点
# FA杯_2022             Colt(Paisley(premier))  /  8点
# FA杯_2023         Salvador(Vienna(premier))  /  12点
# FA杯_2024        Jaffer(Shrewsbury(premier))  /  8点
# FA杯_2025         Trystin(Duisburg(premier))  /  9点
# FA杯_2026           Jaffer(Glasgow(premier))  /  8点
# FA杯_2027  Clerence(Stoke-on-Trent(premier))  /  9点
# FA杯_2028             Jamal(Newark(premier))  /  6点
# FA杯_2029    Mercer(Stoke-on-Trent(premier))  /  5点

# %% [markdown]
# ## チームごとの結果

# %%
league_num = 0
team_num = 4
year = 2029

print(England.leagues[league_num].teams[team_num].name)
b = England.leagues[league_num].teams[team_num].competition_result
display(pd.DataFrame(b.values(), index=b.keys(), columns=["ラウンド"]))
display(England.leagues[league_num].teams[team_num].result)

output = England.players_result
output = output[output["チーム"]==England.leagues[league_num].teams[team_num].name]
output = output[output["分類"]=="リーグ"]
display(output.groupby("uuid").sum()[["試合数", "goal", "assist", "CS"]].sort_values("試合数", ascending=False).head(40))
# Out:
# Geneva
#           ラウンド
# FA杯_2000   1回戦
# FA杯_2001   3回戦
# FA杯_2002   1回戦
# FA杯_2003   2回戦
# FA杯_2004   1回戦
# FA杯_2005   2回戦
# FA杯_2006   1回戦
# FA杯_2007   1回戦
# FA杯_2008   1回戦
# 104781  premier  2029  Geneva  カップ戦  17位    0     0       0   0     0
# 104782  premier  2029  Geneva   リーグ  17位    0     0       0   0     0
# 104783  premier  2029  Geneva  カップ戦  17位    0     0       0   0     0
# 104784  premier  2029  Geneva   リーグ  17位    0     0       0   0     0
# 104785  premier  2029  Geneva  カップ戦  17位    0     0       0   0     0
# 104786  premier  2029  Geneva   リーグ  17位    0     0       0   0     0
# 104787  premier  2029  Geneva  カップ戦  17位    0     0       0   0     0
# 104788  premier  2029  Geneva   リーグ  17位   33     4       2   2     4
# 104789  premier  2029  Geneva  カップ戦  17位    3     0       0   1     0
# 104790  premier  2029  Geneva   リーグ  17位    0     0       0   0     0
# 104791  premier  2029  Geneva  カップ戦  17位    0     0       0   0     0
# 104792  premier  2029  Geneva   リーグ  17位    0     0       0   0     0
# 104793  premier  2029  Geneva  カップ戦  17位    0     0       0   0     0
# 104794  premier  2029  Geneva   リーグ  17位    0     0       0   0     0
# 104795  premier  2029  Geneva  カップ戦  17位    0     0       0   0     0
# 104796  premier  2029  Geneva   リーグ  17位    5     0       1   1     0
# 104797  premier  2029  Geneva  カップ戦  17位    0     0       0   0     0
# 104798  premier  2029  Geneva   リーグ  17位    0     0       0   0     0
# 104799  premier  2029  Geneva  カップ戦  17位    0     0       0   0     0
# 104800  premier  2029  Geneva   リーグ  17位    0     0       0   0     0
# 104801  premier  2029  Geneva  カップ戦  17位    0     0       0   0     0
# 104802  premier  2029  Geneva   リーグ  17位    9     0       0   1    29
# 104803  premier  2029  Geneva  カップ戦  17位    0     0       0   0     2
# 104804  premier  2029  Geneva   リーグ  17位   25     0       0   2    11
# 104805  premier  2029  Geneva  カップ戦  17位    3     0       0   1     0
# 104806  premier  2029  Geneva   リーグ  17位    0     0       0   0     0
# 104807  premier  2029  Geneva  カップ戦  17位    0     0       0   0     0
# 104808  premier  2029  Geneva   リーグ  17位   22     1       1   2    18
# 104809  premier  2029  Geneva  カップ戦  17位    2     0       0   1     2
# 104810  premier  2029  Geneva   リーグ  17位   16     0       0   1    10
# 104811  premier  2029  Geneva  カップ戦  17位    1     0       0   0     2
# 104812  premier  2029  Geneva   リーグ  17位   27     1       1   2     0
# 104813  premier  2029  Geneva  カップ戦  17位    2     0       0   0     0
# 104814  premier  2029  Geneva   リーグ  17位    7     1       1   0     0
# 104815  premier  2029  Geneva  カップ戦  17位    0     0       0   0     0
# 104816  premier  2029  Geneva   リーグ  17位   17     1       1   2    23
# 104817  premier  2029  Geneva  カップ戦  17位    1     0       0   1     2
# 104818  premier  2029  Geneva   リーグ  17位    0     0       0   0     0
# 104819  premier  2029  Geneva  カップ戦  17位    0     0       0   0     0

# %% [markdown]
# ## 選手ごとの結果

# %%
uuid_ = "491bb022-47dd-11ed-b218-00155d14f69a"
print_player(England, all_member, uuid_)
# Out:
#          名前  年齢  生まれ年   成長タイプ
# 274  Mercer  30  1999  legend
#             名前                                  uuid  年齢  Rate  残契約 ポジション  \
# 65452   Mercer  491bb022-47dd-11ed-b218-00155d14f69a  18    68    2  None
# 71266   Mercer  491bb022-47dd-11ed-b218-00155d14f69a  19    69    3    LM
# 74716   Mercer  491bb022-47dd-11ed-b218-00155d14f69a  20    71    2    LW
# 77804   Mercer  491bb022-47dd-11ed-b218-00155d14f69a  21    74    2    RM
# 80362   Mercer  491bb022-47dd-11ed-b218-00155d14f69a  22    76    1    RM
# 84974   Mercer  491bb022-47dd-11ed-b218-00155d14f69a  23    78    0    ST
# 87548   Mercer  491bb022-47dd-11ed-b218-00155d14f69a  24    81    2    ST
# 90966   Mercer  491bb022-47dd-11ed-b218-00155d14f69a  25    84    1    ST
# 94442   Mercer  491bb022-47dd-11ed-b218-00155d14f69a  26    84    0    ST
# 97922   Mercer  491bb022-47dd-11ed-b218-00155d14f69a  27    84    1    ST
# 101400  Mercer  491bb022-47dd-11ed-b218-00155d14f69a  28    84    0    ST
# 105072  Mercer  491bb022-47dd-11ed-b218-00155d14f69a  29    84    1    ST
#
#                  リーグ    年度             チーム   分類   順位  試合数  goal  assist  CS  \
# 65452        premier  2018          Dundee  リーグ  14位    0     0       0   0
# 71266            EFL  2019        Colombes  リーグ  10位   23     5       4   1
# 74716            EFL  2020        Colombes  リーグ  10位   38    13       4   3
# 77804   championship  2021           Crewe  リーグ   1位   12     2       4   5
# 80362        premier  2022           Crewe  リーグ  20位    7     1       0   1
# 84974   championship  2023           Crewe  リーグ   2位   30    20       4  11
# 87548        premier  2024           Crewe  リーグ  17位   35     9       1   5
# 90966        premier  2025           Crewe  リーグ  16位   35    16       4   3
# 94442        premier  2026           Crewe  リーグ  15位   32     7       6   2
# 97922        premier  2027           Crewe  リーグ   1位   25    23       2  17
# 101400       premier  2028           Crewe  リーグ   7位   29    18       3  10
# 105072       premier  2029  Stoke-on-Trent  リーグ   1位   38    44       7  27
#
#         怪我欠場                    賞
# 65452      0
# 71266     14
# 74716      0
# 77804      0
# 80362     24
# 84974      9
# 87548      4
# 90966      3
# 94442      7
# 97922     14
# 101400    11
# 105072     0  得点王(premier_2029),

# %% [markdown]
# ## 年ごとの結果

# %%
year = 2008
league_name = f"{England.leagues[league_num].name}_{year}"
competition_name = f"FA杯_{year}"
England.leagues[league_num].team_result[league_name]
#England.competition_result[competition_name]

# %%
output = England.players_result
output.sort_values("Rate", ascending=False).head(30)

# %%
all_member.sort_values("年齢", ascending=False).head(30)

# %%
all_member[all_member["成長タイプ"]=="legend"]

# %% [markdown]
# ## 全選手成績

# %%
output = England.players_result
#output = output[output["チーム"]==England.leagues[league_num].teams[team_num].name]
#output = output[output["分類"]=="リーグ"]
output.groupby("uuid").sum()[["試合数", "goal", "assist", "CS", "怪我欠場"]].sort_values("assist", ascending=False).head(10)

# %%
uuid_ = "996e1702-47b7-11ed-87b8-00155d14f69a"
print_player(England, all_member, uuid_)

# %%
import pickle

# %%
with open('../data/pickle/20221009v2_30y.pickle', mode='wb') as f:
    pickle.dump(England, f)
