# %%
import numpy as np
import pandas as pd

pd.set_option('display.max_rows', 80)

import random

import time

import sys
sys.path.append("../")

from src.object import *
from src.create import *

from config.formation import *
from config.config import *

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
df_name = pd.read_csv("../data/csv/NationalNames.csv")
df_name_list = list(df_name[df_name.Gender=='M'].Name.sample(1000))

# %%
df_place = pd.read_csv("../data/csv/results.csv")
df_place = df_place.city.unique()
df_place_count = 0

# %%
league_team = []

for i in range(20):
    mean_rate = np.random.normal(68, 1)
    Cp = Create_player(position_num={"ST":4, "RW":2, "CAM":3, "RM":2, "CM":5, "CDM":3, "CB":4, "RB":4, "GK":3}, 
                       min_rate=0, max_rate=100, 
                       age_mean=27,
                       mean_rate=mean_rate,
                       df_name_list=df_name_list)
    Cp.create_teams()
    players = Cp.players
    formation = random_create_formation()
    A = Team(name=df_place[df_place_count], 
             formation=formation,
             min_rate=0,#これたぶんいらない
             max_rate=100)#これもいらない
    A.affilation_players = players
    
    league_team.append(A)
    df_place_count += 1

L1 = League(name="premier", 
            teams=league_team,
            num=20,
            min_rate=75,
            max_rate=99,
            mean_rate=68,
            category='top',
            relegation_num=3)

# %%
league_team = []

for i in range(20):
    mean_rate = np.random.normal(63, 1)
    Cp = Create_player(position_num={"ST":4, "RW":2, "CAM":3, "RM":2, "CM":5, "CDM":3, "CB":4, "RB":4, "GK":3}, 
                       min_rate=0, max_rate=100, 
                       age_mean=27,
                       mean_rate=mean_rate,
                       df_name_list=df_name_list)
    Cp.create_teams()
    players = Cp.players
    formation = random_create_formation()
    A = Team(name=df_place[df_place_count], 
             formation=formation,
             min_rate=0,
             max_rate=100)
    A.affilation_players = players
    
    league_team.append(A)
    df_place_count += 1

L2 = League(name="championship",
            teams=league_team,
            num=20,
            min_rate=63,
            max_rate=78,
            mean_rate=63,
            category='middle',
            relegation_num=3,
            promotion_num=3)

# %%
league_team = []

for i in range(20):
    mean_rate = np.random.normal(58, 1)
    Cp = Create_player(position_num={"ST":4, "RW":2, "CAM":3, "RM":2, "CM":5, "CDM":3, "CB":4, "RB":4, "GK":3}, 
                       min_rate=0, max_rate=100, 
                       age_mean=27,
                       mean_rate=mean_rate,
                       df_name_list=df_name_list)
    Cp.create_teams()
    players = Cp.players
    formation = random_create_formation()
    A = Team(name=df_place[df_place_count], 
             formation=formation,
             min_rate=0,
             max_rate=100)
    A.affilation_players = players
    
    league_team.append(A)
    df_place_count += 1

L3 = League(name="EFL",
            teams=league_team,
            num=20,
            min_rate=0,
            max_rate=73,
            mean_rate=59,
            category='lowest',
            relegation_num=0,
            promotion_num=3)

# %%
England = ProSoccerLeague(name="england", leagues=[L1, L2, L3])

for year in range(2000,  2020):
    print(year)
    competition = Competition(name=f"FA杯_{year}")

    England.play_1season(year, competition)
    England.play_offseason(df_name_list)
# Out:
# 2000
# 100%|███████████████████████████████████████████████████████████████████████████████████| 38/38 [00:43<00:00,  1.14s/it]
# 2001
# 100%|███████████████████████████████████████████████████████████████████████████████████| 38/38 [00:40<00:00,  1.07s/it]
# 2002
# 100%|███████████████████████████████████████████████████████████████████████████████████| 38/38 [00:41<00:00,  1.10s/it]
# 2003
# 100%|███████████████████████████████████████████████████████████████████████████████████| 38/38 [00:42<00:00,  1.11s/it]
# 2004
# 100%|███████████████████████████████████████████████████████████████████████████████████| 38/38 [00:53<00:00,  1.40s/it]
# 2005
# 100%|███████████████████████████████████████████████████████████████████████████████████| 38/38 [00:49<00:00,  1.30s/it]
# 2006
# 100%|███████████████████████████████████████████████████████████████████████████████████| 38/38 [00:54<00:00,  1.42s/it]
# 2007
# 100%|███████████████████████████████████████████████████████████████████████████████████| 38/38 [00:49<00:00,  1.30s/it]
# 2008
# 100%|███████████████████████████████████████████████████████████████████████████████████| 38/38 [00:50<00:00,  1.32s/it]
# 2009
# 100%|███████████████████████████████████████████████████████████████████████████████████| 38/38 [00:50<00:00,  1.34s/it]
# 2010
# 100%|███████████████████████████████████████████████████████████████████████████████████| 38/38 [00:48<00:00,  1.26s/it]
# 2011
# 100%|███████████████████████████████████████████████████████████████████████████████████| 38/38 [00:50<00:00,  1.33s/it]
# 2012
# 100%|███████████████████████████████████████████████████████████████████████████████████| 38/38 [00:51<00:00,  1.36s/it]
# 2013
# 100%|███████████████████████████████████████████████████████████████████████████████████| 38/38 [00:50<00:00,  1.34s/it]
# 2014
# 100%|███████████████████████████████████████████████████████████████████████████████████| 38/38 [00:53<00:00,  1.39s/it]
# 2015
# 100%|███████████████████████████████████████████████████████████████████████████████████| 38/38 [00:40<00:00,  1.06s/it]
# 2016
# 100%|███████████████████████████████████████████████████████████████████████████████████| 38/38 [00:41<00:00,  1.08s/it]
# 2017
# 100%|███████████████████████████████████████████████████████████████████████████████████| 38/38 [00:41<00:00,  1.10s/it]
# 2018
# 100%|███████████████████████████████████████████████████████████████████████████████████| 38/38 [00:42<00:00,  1.11s/it]
# 2019
# 100%|███████████████████████████████████████████████████████████████████████████████████| 38/38 [00:42<00:00,  1.12s/it]

# %%
#England = ProSoccerLeague(name="england", leagues=[L1, L2, L3])
all_member = pd.DataFrame()
for l in England.leagues:
    for t in l.teams:
        for p in t.affilation_players:
            buff = pd.DataFrame(np.array([[p.name, t.name, p.uuid, p.age, p.main_position, p.main_rate, p.pace, p.shooting, p.passing, p.dribbling, p.defending, p.physicality, "現役"]]), 
                                columns = ["名前", "チーム", "uuid", "年齢", "ポジション", "Rate", "pac", "sho", "pas", "dri", "def", "phy", "進退"])
            all_member = pd.concat([all_member, buff])
for p in England.retire_players:
    buff = pd.DataFrame(np.array([[p.name, t.name, p.uuid, p.age, p.main_position, p.main_rate, p.pace, p.shooting, p.passing, p.dribbling, p.defending, p.physicality, "引退"]]), 
                        columns = ["名前", "チーム", "uuid", "年齢", "ポジション", "Rate", "pac", "sho", "pas", "dri", "def", "phy", "進退"])
    all_member = pd.concat([all_member, buff])

for p in England.free_players:
    buff = pd.DataFrame(np.array([[p.name, t.name, p.uuid, p.age, p.main_position, p.main_rate, p.pace, p.shooting, p.passing, p.dribbling, p.defending, p.physicality, "フリー"]]), 
                        columns = ["名前", "チーム", "uuid", "年齢", "ポジション", "Rate", "pac", "sho", "pas", "dri", "def", "phy", "進退"])
    all_member = pd.concat([all_member, buff])
all_member = all_member.reset_index(drop=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 2
#       1 #England = ProSoccerLeague(name="england", leagues=[L1, L2, L3])
# ----> 2 all_member = pd.DataFrame()
#       3 for l in England.leagues:
#       4     for t in l.teams:
#
# NameError: name 'pd' is not defined

# %% [markdown]
# # 結果一覧

# %% [markdown]
# ## リーグ・カップ戦結果

# %%
league_num = 0

print("チーム一覧")
print([t.name for t in England.leagues[league_num].teams])

England.leagues[0].champion
England.leagues[1].champion
England.leagues[2].champion

England.competition_result_top
# Out:
# チーム一覧
# ['Newark', 'Bangor', 'Montevideo', 'Richmond', 'Sheffield', 'Wolverhampton', 'Dublin', 'Dundee', 'Bristol', 'Paisley', 'London', 'Derby', 'Glasgow', 'Motherwell', 'Aberdeen', 'Birmingham', 'Portsmouth', 'Sunderland', 'Belfast', 'Budapest']
#                          優勝                            得点王
# premier_2000     Birmingham       Colbe(Edinburgh)  /  19点
# premier_2001     Birmingham           Cody(Bangor)  /  17点
# premier_2002     Montevideo         Keshav(Newark)  /  23点
# premier_2003        Glasgow      Amjad(Birmingham)  /  24点
# premier_2004     Manchester      Arturo(Edinburgh)  /  18点
# premier_2005      Edinburgh      Colbe(Sunderland)  /  22点
# premier_2006      Newcastle  Liamjames(Montevideo)  /  27点
# premier_2007        Glasgow  Liamjames(Montevideo)  /  30点
# premier_2008        Swansea    Branson(Kilmarnock)  /  26点
# premier_2009         Newark          Simon(Newark)  /  44点
# premier_2010     Kilmarnock     Haskel(Kilmarnock)  /  39点
# premier_2011     Shrewsbury     Calvin(Shrewsbury)  /  36点
# premier_2012         Newark    Melvine(Manchester)  /  19点
# premier_2013     Montevideo   Elbridge(Portsmouth)  /  31点
# premier_2014         Dublin   Elbridge(Portsmouth)  /  24点
# premier_2015         Bangor   Elbridge(Portsmouth)  /  26点
# premier_2016         Bangor     Tlaloc(Montevideo)  /  22点
# premier_2017  Wolverhampton   Vegas(Wolverhampton)  /  30点
# premier_2018         Newark   Vegas(Wolverhampton)  /  22点
# premier_2019         Newark   Vegas(Wolverhampton)  /  29点
#                               優勝                              得点王
# championship_2000     Kilmarnock        Lando(Kilmarnock)  /  26点
# championship_2001         London            Taran(Dundee)  /  36点
# championship_2002      Newcastle         Dannen(Greenock)  /  24点
# championship_2003       Richmond            Taran(Dundee)  /  33点
# championship_2004        Wrexham            Cody(Wrexham)  /  34点
# championship_2005  Wolverhampton       Tristin(Blackburn)  /  27点
# championship_2006       Richmond         Ferlin(Brussels)  /  25点
# championship_2007     Manchester    Mannie(Wolverhampton)  /  26点
# championship_2008        Bristol  Detavious(Buenos Aires)  /  32点
# championship_2009         London           Glover(London)  /  27点
# championship_2010    Southampton      Dillard(Portsmouth)  /  27点
# championship_2011        Wrexham       Kendal(Sunderland)  /  26点
# championship_2012     Portsmouth            Jvon(Glasgow)  /  27点
# championship_2013   Buenos Aires         Vitor(Blackburn)  /  25点
# championship_2014       Budapest          Arvin(Duisburg)  /  22点
# championship_2015         London          Latroy(Wrexham)  /  28点
# championship_2016     Motherwell         Lark(Motherwell)  /  31点
# championship_2017       Budapest          Torre(Aberdeen)  /  27点
# championship_2018     Manchester    Rayburn(Buenos Aires)  /  22点
# championship_2019     Sunderland             Vitor(Crewe)  /  22点
#                    優勝                          得点王
# EFL_2000       Prague   Watson(Kristiania)  /  32点
# EFL_2001       Dublin     Ildefonso(Paris)  /  33点
# EFL_2002     Aberdare    Zorian(Karlsruhe)  /  40点
# EFL_2003        Paris        Rowen(Vienna)  /  34点
# EFL_2004   Motherwell   Kendal(Motherwell)  /  29点
# EFL_2005  Southampton  Jayson(Southampton)  /  41点
# EFL_2006     Aberdare       Scott(Antwerp)  /  32点
# EFL_2007       Vienna   Almando(Karlsruhe)  /  39点
# EFL_2008    Llandudno      Malvin(Antwerp)  /  33点
# EFL_2009     Gentilly  Jaquae(Saint-Cloud)  /  35点
# EFL_2010        Paris      Arpan(Aberdare)  /  39点
# EFL_2011   Kristiania     Dwight(Gentilly)  /  44点
# EFL_2012     Aberdare     Lark(Motherwell)  /  40点
# EFL_2013     Greenock      Janai(Greenock)  /  40点
# EFL_2014      Cardiff       Dokota(Arnhem)  /  33点
# EFL_2015     Aberdare   Hardwick(Brussels)  /  31点
# EFL_2016      Antwerp     Charlee(Cardiff)  /  39点
# EFL_2017       Vienna      Marquece(Milan)  /  42点
# EFL_2018    Karlsruhe    Dillard(Greenock)  /  38点
# EFL_2019       Geneva       Moss(Brussels)  /  36点
#             年度                       優勝                      準優勝  \
# FA杯_2000  2000          Newark(premier)      Birmingham(premier)
# FA杯_2001  2001          Bangor(premier)         Swansea(premier)
# FA杯_2002  2002  Stoke-on-Trent(premier)         Swansea(premier)
# FA杯_2003  2003          Bangor(premier)         Wrexham(premier)
# FA杯_2004  2004         Bristol(premier)           Crewe(premier)
# FA杯_2005  2005         Glasgow(premier)          Newark(premier)
# FA杯_2006  2006      Montevideo(premier)         Bristol(premier)
# FA杯_2007  2007         Glasgow(premier)         Paisley(premier)
# FA杯_2008  2008      Kilmarnock(premier)       Newcastle(premier)
# FA杯_2009  2009          Newark(premier)      Montevideo(premier)
# FA杯_2010  2010         Bristol(premier)      Shrewsbury(premier)
# FA杯_2011  2011      Shrewsbury(premier)   Wolverhampton(premier)
# FA杯_2012  2012          Newark(premier)          London(premier)
# FA杯_2013  2013      Montevideo(premier)         Wrexham(premier)
# FA杯_2014  2014          Newark(premier)        Richmond(premier)
# FA杯_2015  2015     London(championship)      Birmingham(premier)
# FA杯_2016  2016      Birmingham(premier)      Montevideo(premier)
# FA杯_2017  2017      Motherwell(premier)         Bristol(premier)
# FA杯_2018  2018   Wolverhampton(premier)  Edinburgh(championship)
# FA杯_2019  2019         Glasgow(premier)          Dundee(premier)
#
#                                              得点王
# FA杯_2000          Keshav(Newark(premier))  /  7点
# FA杯_2001         Reyhan(Swansea(premier))  /  7点
# FA杯_2002         Shedrick(Crewe(premier))  /  5点
# FA杯_2003          Arturo(London(premier))  /  7点
# FA杯_2004             July(Crewe(premier))  /  5点
# FA杯_2005          Eugen(Paisley(premier))  /  8点
# FA杯_2006        Rahil(Blackburn(premier))  /  6点
# FA杯_2007        Almando(Glasgow(premier))  /  7点
# FA杯_2008     Branson(Kilmarnock(premier))  /  7点
# FA杯_2009          Simon(Newark(premier))  /  10点
# FA杯_2010     Calvin(Shrewsbury(premier))  /  10点
# FA杯_2011      Calvin(Shrewsbury(premier))  /  8点
# FA杯_2012           Oliva(Newark(premier))  /  8点
# FA杯_2013   Cristofer(Montevideo(premier))  /  5点
# FA杯_2014           Brown(Newark(premier))  /  7点
# FA杯_2015  Donchevell(Birmingham(premier))  /  8点
# FA杯_2016       Jancarlos(Dublin(premier))  /  7点
# FA杯_2017         Kameran(Bangor(premier))  /  5点
# FA杯_2018    Vegas(Wolverhampton(premier))  /  7点
# FA杯_2019          Dowell(Dundee(premier))  /  7点

# %% [markdown]
# ## チームごとの結果

# %%
team_num = 4
year = 2000

print(England.leagues[league_num].teams[team_num].name)
b = England.leagues[league_num].teams[team_num].competition_result
pd.DataFrame(b.values(), index=b.keys(), columns=["ラウンド"])
England.leagues[league_num].teams[team_num].result

output = England.players_result
output = output[output["チーム"]==England.leagues[league_num].teams[team_num].name]
output = output[output["分類"]=="リーグ"]
output.groupby("uuid").sum()[["ポジション", "試合数", "goal", "assist", "CS"]].sort_values("試合数", ascending=False).head(40)
# Out:
# Sheffield
#           ラウンド
# 2010  championship   リーグ  2000  Montevideo  2位  25    3      3   8   15
# 2011  championship  カップ戦  2000  Montevideo  2位   2    0      1   0    1
# 2012  championship   リーグ  2000  Montevideo  2位  31    1      3   9    8
# 2013  championship  カップ戦  2000  Montevideo  2位   3    0      0   1    0
# 2014  championship   リーグ  2000  Montevideo  2位   0    0      0   0    0
# 2015  championship  カップ戦  2000  Montevideo  2位   0    0      0   0    0
# 2016  championship   リーグ  2000  Montevideo  2位   6    0      0   4    0
# 2017  championship  カップ戦  2000  Montevideo  2位   0    0      0   0    0
# 2018  championship   リーグ  2000  Montevideo  2位  13    0      0   3   14
# 2019  championship  カップ戦  2000  Montevideo  2位   1    2      0   0    2
# 2020  championship   リーグ  2000  Montevideo  2位  11    2      0   4    8
# 2021  championship  カップ戦  2000  Montevideo  2位   2    0      0   1    0
# 2022  championship   リーグ  2000  Montevideo  2位   5    0      1   3    0
# 2023  championship  カップ戦  2000  Montevideo  2位   0    0      0   0    0
# 2024  championship   リーグ  2000  Montevideo  2位  19    1      1   6   17
# 2025  championship  カップ戦  2000  Montevideo  2位   1    0      1   0    2
# 2026  championship   リーグ  2000  Montevideo  2位  23    1      0  11   17
# 2027  championship  カップ戦  2000  Montevideo  2位   1    0      0   0    2
# 2028  championship   リーグ  2000  Montevideo  2位   3    0      0   2    6
# 2029  championship  カップ戦  2000  Montevideo  2位   0    0      0   0    0
# 2030  championship   リーグ  2000  Montevideo  2位  24    2      3  11   15
# 2031  championship  カップ戦  2000  Montevideo  2位   2    0      0   1    2
# 2032  championship   リーグ  2000  Montevideo  2位  23    1      1   5   17
# 2033  championship  カップ戦  2000  Montevideo  2位   2    0      0   1    1
# 2034  championship   リーグ  2000  Montevideo  2位   0    0      0   0    0
# 2035  championship  カップ戦  2000  Montevideo  2位   0    0      0   0    0
# 2036  championship   リーグ  2000  Montevideo  2位  38    0      0  13    0
# 2037  championship  カップ戦  2000  Montevideo  2位   3    0      0   1    0
# 2038  championship   リーグ  2000  Montevideo  2位   0    0      0   0    0
# 2039  championship  カップ戦  2000  Montevideo  2位   0    0      0   0    0

# %% [markdown]
# ## 選手ごとの結果

# %%
uuid_ = "7731e2a8-44d9-11ed-aa23-00155d19776f"
all_member[all_member.uuid==uuid.UUID(f"{uuid_}")]

output = England.players_result
output = output[output.uuid==uuid.UUID(f"{uuid_}")]
output[output["分類"]=="リーグ"]
# Out:
# Empty DataFrame
# Columns: [名前, uuid, 年齢, ポジション, Rate, pac, sho, pas, dri, def, phy, 進退]
# Index: []
# Empty DataFrame
# Columns: [名前, 年齢, Rate, uuid, ポジション, リーグ, 分類, 年度, チーム, 順位, 試合数, goal, assist, CS, 怪我欠場, 賞]
# Index: []

# %% [markdown]
# ## 年ごとの結果

# %%
year = 2008
league_name = f"{England.leagues[league_num].name}_{year}"
competition_name = f"FA杯_{year}"
England.leagues[league_num].team_result[league_name]
#England.competition_result[competition_name]
# Out:
#                 win  lose  row  得点   失点  得失点差  Points   順位     リーグ名
# Swansea          32     2    4  99   22    77     100   1位  premier
# Bangor           29     5    4  87   24    63      91   2位  premier
# Kilmarnock       29     5    4  97   20    77      91   3位  premier
# Newark           24     9    5  69   29    40      77   4位  premier
# Richmond         22     7    9  87   37    50      75   5位  premier
# Sheffield        22     9    7  79   39    40      73   6位  premier
# Wolverhampton    20    12    6  66   49    17      66   7位  premier
# Newcastle        19    12    7  54   37    17      64   8位  premier
# Crewe            19    13    6  67   51    16      63   9位  premier
# Wrexham          15    16    7  45   55   -10      52  10位  premier
# Montevideo       14    16    8  46   52    -6      50  11位  premier
# Stoke-on-Trent   13    17    8  52   65   -13      47  12位  premier
# Paisley          10    19    9  37   55   -18      39  13位  premier
# Glasgow          10    23    5  35   72   -37      35  14位  premier
# Sunderland        9    23    6  34   62   -28      33  15位  premier
# Shrewsbury        8    23    7  38   80   -42      31  16位  premier
# Birmingham        7    22    9  30   64   -34      30  17位  premier
# London            8    25    5  48   92   -44      29  18位  premier
# Manchester        4    28    6  19   94   -75      18  19位  premier
# Belfast           2    30    6  24  114   -90      12  20位  premier

# %%
output = England.players_result
output.sort_values("Rate", ascending=False).head(30)
# Out:
#               名前  年齢 Rate                                  uuid ポジション  \
# 3775   Shermaine  32   95  df90f194-4598-11ed-93f8-00155d19776f    GK
# 3774   Shermaine  32   95  df90f194-4598-11ed-93f8-00155d19776f    GK
# 1077   Shermaine  31   95  df90f194-4598-11ed-93f8-00155d19776f    GK
# 1076   Shermaine  31   95  df90f194-4598-11ed-93f8-00155d19776f    GK
# 15359  Shermaine  35   95  df90f194-4598-11ed-93f8-00155d19776f    GK
# 15358  Shermaine  35   95  df90f194-4598-11ed-93f8-00155d19776f    GK
# 65202     Weston  26   94  9878c5f4-459b-11ed-93f8-00155d19776f    GK
# 68723     Weston  27   94  9878c5f4-459b-11ed-93f8-00155d19776f    GK
# 65203     Weston  26   94  9878c5f4-459b-11ed-93f8-00155d19776f    GK
# 61678     Weston  25   94  9878c5f4-459b-11ed-93f8-00155d19776f    GK
# 61679     Weston  25   94  9878c5f4-459b-11ed-93f8-00155d19776f    GK
# 68722     Weston  27   94  9878c5f4-459b-11ed-93f8-00155d19776f    GK
# 7963        Tage  32   93  df2f1e4c-4598-11ed-93f8-00155d19776f    CB
# 11473       Tage  33   93  df2f1e4c-4598-11ed-93f8-00155d19776f    CB
# 11472       Tage  33   93  df2f1e4c-4598-11ed-93f8-00155d19776f    CB
# 19077    Flossie  32   93  dfb5e418-4598-11ed-93f8-00155d19776f    GK
# 25799    Flossie  34   93  dfb5e418-4598-11ed-93f8-00155d19776f    GK
# 25798    Flossie  34   93  dfb5e418-4598-11ed-93f8-00155d19776f    GK
# 390         Tage  30   93  df2f1e4c-4598-11ed-93f8-00155d19776f    CB
# 19076    Flossie  32   93  dfb5e418-4598-11ed-93f8-00155d19776f    GK
# 1258     Flossie  27   93  dfb5e418-4598-11ed-93f8-00155d19776f    GK
# 1259     Flossie  27   93  dfb5e418-4598-11ed-93f8-00155d19776f    GK
# 391         Tage  30   93  df2f1e4c-4598-11ed-93f8-00155d19776f    CB
# 7962        Tage  32   93  df2f1e4c-4598-11ed-93f8-00155d19776f    CB
# 4663     Flossie  28   93  dfb5e418-4598-11ed-93f8-00155d19776f    GK
# 22518    Flossie  33   93  dfb5e418-4598-11ed-93f8-00155d19776f    GK
# 22519    Flossie  33   93  dfb5e418-4598-11ed-93f8-00155d19776f    GK
# 3921        Tage  31   93  df2f1e4c-4598-11ed-93f8-00155d19776f    CB
# 3920        Tage  31   93  df2f1e4c-4598-11ed-93f8-00155d19776f    CB
# 4662     Flossie  28   93  dfb5e418-4598-11ed-93f8-00155d19776f    GK
#
#                 リーグ    分類    年度         チーム   順位 試合数 goal assist  CS 怪我欠場 賞
# 3775        premier  カップ戦  2001   Blackburn   6位   4    0      0   0    0
# 3774        premier   リーグ  2001   Blackburn   6位  38    0      0  17    0
# 1077        premier  カップ戦  2000  Birmingham   1位   6    0      0   3    0
# 1076        premier   リーグ  2000  Birmingham   1位  38    0      0  21    0
# 15359       premier  カップ戦  2004     Bristol   5位   6    0      0   2    0
# 15358       premier   リーグ  2004     Bristol   5位  38    0      0  12    0
# 65202       premier   リーグ  2018   Sheffield   5位  38    0      0  15    0
# 68723       premier  カップ戦  2019   Sheffield   3位   4    0      0   1    0
# 65203       premier  カップ戦  2018   Sheffield   5位   2    0      0   0    0
# 61678       premier   リーグ  2017   Sheffield  15位  38    0      0  13    0
# 61679       premier  カップ戦  2017   Sheffield  15位   1    0      0   0    0
# 68722       premier   リーグ  2019   Sheffield   3位  38    0      0  15    0
# 7963        premier  カップ戦  2002  Birmingham  13位   1    0      0   0    0
# 11473       premier  カップ戦  2003  Birmingham   2位   2    0      0   0    0
# 11472       premier   リーグ  2003  Birmingham   2位  38    9      8  14    0
# 19077       premier  カップ戦  2005     Wrexham  15位   5    0      0   2    0
# 25799       premier  カップ戦  2007     Paisley   9位   6    0      0   2    0
# 25798       premier   リーグ  2007     Paisley   9位  38    0      0  18    0
# 390         premier   リーグ  2000   Sheffield   8位  32    0      1   6    7
# 19076       premier   リーグ  2005     Wrexham  15位  38    0      0   9    0
# 1258   championship   リーグ  2000  Kilmarnock   1位  38    0      0   8    0
# 1259   championship  カップ戦  2000  Kilmarnock   1位   2    0      0   0    0
# 391         premier  カップ戦  2000   Sheffield   8位   1    0      0   0    0
# 7962        premier   リーグ  2002  Birmingham  13位  38    4      2   9    0
# 4663        premier  カップ戦  2001  Kilmarnock  17位   3    0      0   1    0
# 22518       premier   リーグ  2006     Wrexham   6位  38    0      0  11    0
# 22519       premier  カップ戦  2006     Wrexham   6位   2    0      0   0    0
# 3921        premier  カップ戦  2001   Sheffield  19位   2    0      0   0    0
# 3920        premier   リーグ  2001   Sheffield  19位  33    1      2   2    6
# 4662        premier   リーグ  2001  Kilmarnock  17位  38    0      0   6    0

# %%
all_member.sort_values("Rate", ascending=False).head(30)
# Out:
#                名前                                  uuid  年齢 ポジション Rate pac  \
# 2365    Shermaine  df90f194-4598-11ed-93f8-00155d19776f  36    GK   95  15
# 139        Weston  9878c5f4-459b-11ed-93f8-00155d19776f  28    GK   94  15
# 2773  15  15  15  15  15  引退
# 2355  42  81  80  85  69  引退
# 3972  15  15  15  15  15  引退
# 3083  83  81  81  38  64  引退
# 2370  82  58  72  34  61  引退
# 3231  39  59  67  77  77  引退
# 2618  42  45  64  78  78  引退
# 2518  86  81  80  70  74  引退
# 2577  32  55  70  79  79  引退
# 2643  74  83  83  40  62  引退
# 2648  40  57  72  80  80  引退
# 2655  81  68  73  28  69  引退

# %% [markdown]
# ## 全選手成績

# %%
output = England.players_result
#output = output[output["チーム"]==England.leagues[league_num].teams[team_num].name]
#output = output[output["分類"]=="リーグ"]
output.groupby("uuid").sum()[["ポジション", "試合数", "goal", "assist", "CS", "怪我欠場"]].sort_values("試合数", ascending=False).head(1500)
# Out:
#                                                                                   ポジション  \
# uuid
# 2296b62c-4599-11ed-93f8-00155d19776f  LBLBCDMCDMCMCMLBLBCMCMCMCMCBCBCMCMCMCMCMCMCBCB...
# 229bff06-4599-11ed-93f8-00155d19776f  LBLBLBLBLBLBLBLBRMRMRBRBLBLBRBRBLBLBLBLBRBRBRW...
# 228ecaf2-4599-11ed-93f8-00155d19776f  LMLMLMLMLMLMLMLMLWLWRWRWLWLWLWLWLWLWSTSTLWLWLB...
# 43c23d08-4599-11ed-93f8-00155d19776f  CMCMCMCMCMCMLWLWLWLWCMCMCMCMCBCBLBLBLWLWLBLBLB...
# 02830110-4599-11ed-93f8-00155d19776f  LMLMRMRMLMLMLMLMCMCMLWLWCMCMCMCMCMCMCMCMRWRWLW...
# ...                                                                                 ...
# e03b6278-4598-11ed-93f8-00155d19776f                                   CBCBCBCBCBCBLBLB
# df2cc6ba-4598-11ed-93f8-00155d19776f                                   STSTLMLMSTSTLMLM
# 4ac55408-459b-11ed-93f8-00155d19776f                               CMCMCMCMCMCMCMCMCMCM
# dff8bcca-4598-11ed-93f8-00155d19776f                           CMCMCMCMCMCMLBLBRMRMRMRM
# 3ee4050e-459a-11ed-93f8-00155d19776f                       STSTLMLMSTSTCMCMCMCMCMCMCMCM
#
#                                       試合数  goal  assist  CS  怪我欠場
# uuid
# 2296b62c-4599-11ed-93f8-00155d19776f  549    68      97  82   100
# 229bff06-4599-11ed-93f8-00155d19776f  541    25      33  83    19
# 228ecaf2-4599-11ed-93f8-00155d19776f  534   132      65  90    71
# 43c23d08-4599-11ed-93f8-00155d19776f  523    64      73  88   126
# 02830110-4599-11ed-93f8-00155d19776f  516   136      70  89    19
# ...                                   ...   ...     ...  ..   ...
# e03b6278-4598-11ed-93f8-00155d19776f  149     3       6  38    18
# df2cc6ba-4598-11ed-93f8-00155d19776f  149    45      18  37     0
# 4ac55408-459b-11ed-93f8-00155d19776f  149    23      21  28    55
# dff8bcca-4598-11ed-93f8-00155d19776f  149    19      22  33     0
# 3ee4050e-459a-11ed-93f8-00155d19776f  149    29      25  34    17
#
# [1500 rows x 6 columns]

# %%
uuid_ = "dfa85190-4598-11ed-93f8-00155d19776f"
all_member[all_member.uuid==uuid.UUID(f"{uuid_}")]

output = England.players_result
output = output[output.uuid==uuid.UUID(f"{uuid_}")]
output[output["分類"]=="リーグ"]
#output
# Out:
#          名前                                  uuid  年齢 ポジション Rate pac sho pas  \
# 2505  Lando  dfa85190-4598-11ed-93f8-00155d19776f  34   CAM   88  60  85  84
#
#      dri def phy  進退
# 2505  84  42  76  引退
#           名前  年齢 Rate                                  uuid ポジション  \
# 1210   Lando  28   88  dfa85190-4598-11ed-93f8-00155d19776f    ST
# 4626   Lando  29   88  dfa85190-4598-11ed-93f8-00155d19776f    ST
# 8102   Lando  30   88  dfa85190-4598-11ed-93f8-00155d19776f    ST
# 11732  Lando  31   88  dfa85190-4598-11ed-93f8-00155d19776f    ST
# 15194  Lando  32   88  dfa85190-4598-11ed-93f8-00155d19776f    ST
# 18692  Lando  33   88  dfa85190-4598-11ed-93f8-00155d19776f    ST
#
#                 リーグ   分類    年度         チーム   順位 試合数 goal assist  CS 怪我欠場  \
# 1210   championship  リーグ  2000  Kilmarnock   1位  32   26      6   6    7
# 4626        premier  リーグ  2001  Kilmarnock  17位  25    5      3   4   15
# 8102        premier  リーグ  2002  Kilmarnock  20位  24    7      2   1   17
# 11732       premier  リーグ  2003  Manchester   6位  21    5      1  10   19
# 15194       premier  リーグ  2004  Manchester   1位  26   13      3   5   13
# 18692       premier  リーグ  2005  Manchester   4位  18    6      1   4   24
#
#                               賞
# 1210   得点王(championship_2000),
# 4626
# 8102
# 11732
# 15194
# 18692

# %%
k = [i for i in England.leagues[0].teams[4].affilation_players if i.name=="Weston"]

# %%
k[0].diving
# Out:
# 92

# %%
England.leagues[0].teams[4].formation.print_formation()
# Out:
# Lennard   Rate: 76 ( ST )
# -------------------------
#   PAC  57   DRI  68
#   SHO  77   DEF  55
#   PAS  68   PHY  67
#
# Keno   Rate: 72 ( ST )
# -------------------------
#   PAC  61   DRI  63
#   SHO  72   DEF  58
#   PAS  63   PHY  60
#
# Cray   Rate: 68 ( LM )
# -------------------------
#   PAC  64   DRI  67
#   SHO  72   DEF  62
#   PAS  67   PHY  65
#
# Codi   Rate: 67 ( RM )
# -------------------------
#   PAC  69   DRI  61
#   SHO  68   DEF  37
#   PAS  71   PHY  67
#
# Skyy   Rate: 69 ( CM )
# -------------------------
#   PAC  55   DRI  72
#   SHO  61   DEF  67
#   PAS  71   PHY  67
#
# Tyquan   Rate: 69 ( CM )
# -------------------------
#   PAC  76   DRI  67
#   SHO  40   DEF  69
#   PAS  70   PHY  68
#
# Oracio   Rate: 68 ( LB )
# -------------------------
#   PAC  72   DRI  70
#   SHO  39   DEF  73
#   PAS  69   PHY  72
#
# Nevada   Rate: 71 ( CB )
# -------------------------
#   PAC  70   DRI  54
#   SHO  47   DEF  71
#   PAS  62   PHY  71
#
# Dmarius   Rate: 70 ( CB )
# -------------------------
#   PAC  80   DRI  57
#   SHO  44   DEF  75
#   PAS  67   PHY  75
#
# Willian   Rate: 68 ( RB )
# -------------------------
#   PAC  73   DRI  59
#   SHO  32   DEF  72
#   PAS  72   PHY  71
#
# Weston   Rate: 94 ( GK )
# -------------------------
#   DIV  92   REF  94
#   HAN  91   SPE  85
#   KIC  76   POS  92
