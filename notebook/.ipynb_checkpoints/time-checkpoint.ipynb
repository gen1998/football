# %%
import numpy as np
import pandas as pd

pd.set_option('display.max_rows', 80)

import random

import time

import sys
sys.path.append("../")

from src.object import *
from src.create import *

from config.formation import *

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
df_name = pd.read_csv("../data/csv/NationalNames.csv")
df_name_list = list(df_name[df_name.Gender=='M'].Name.sample(500))

# %%
df_place = pd.read_csv("../data/csv/results.csv")
df_place = df_place.city.unique()

# %%
league_team = []

for i in range(20):
    min_rate = np.random.randint(70, 78)
    max_rate = min_rate + 15
    players = random_create_players(27, 3, min_rate, max_rate, df_name_list)
    formation = random_create_formation()
    A = Team(name=df_place[i], 
             formation=formation)
    A.affilation_players = players
    
    league_team.append(A)

L1 = League(name="premia", 
            teams=league_team,
            num=20,
            category='top',
            relegation_num=3)

# %%
league_team = []

for i in range(20):
    min_rate = np.random.randint(60, 70)
    max_rate = min_rate + 15
    players = random_create_players(27, 3, min_rate, max_rate, df_name_list)
    formation = random_create_formation()
    A = Team(name=df_place[i+20], formation=formation)
    A.affilation_players = players
    
    league_team.append(A)

L2 = League(name="championship",
            teams=league_team,
            num=20,
            category='lowest',
            relegation_num=0,
            promotion_num=3)

# %%
year = 1990

England = ProSoccerLeague(name="england", leagues=[L1, L2])

for year in range(1990, 1991):
    print(year)
    competition = Competition(name=f"FA杯_{year}")

    England.play_1season(year, competition)
# Out:
# 1990
# 100%|███████████████████████████████████████████████████████████████████████████████████| 38/38 [00:14<00:00,  2.64it/s]

# %%
England.leagues[0].player_result["premia_1990"].sort_values("goal")
# Out:
#            名前 ポジション     リーグ    年度         チーム 試合数 goal assist   分類
# 398   Merrell    RB  premia  1990     Swansea   4    0      0  リーグ
# 156   Kendale    LW  premia  1990  Manchester   5    0      0  リーグ
# 157    Braden    LW  premia  1990  Manchester   4    0      0  リーグ
# 367     Avian   CDM  premia  1990    Richmond  31    0      4  リーグ
# 160      Norm    RB  premia  1990  Manchester   2    0      0  リーグ
# ..        ...   ...     ...   ...         ...  ..  ...    ...  ...
# 39    Dorothy    ST  premia  1990      London  29   15      0  リーグ
# 204      Jori    ST  premia  1990       Crewe  24   15      0  リーグ
# 393    Walton    ST  premia  1990     Swansea  38   23      6  リーグ
# 358       Khi    ST  premia  1990    Richmond  38   25      5  リーグ
# 323  Cheyenne    ST  premia  1990      Bangor  38   25      3  リーグ
#
# [399 rows x 9 columns]

# %%
England.leagues[0].teams[0].affilation_players_all_rate
# Out:
#     ST  CF  CAM  RW  LW  RM  LM  CM  CDM  RB  LB  CB  RWB  LWB  injury  \
# 0   65  58   58  60  60  60  60  56   65  68  68  74   69   69       0
# 1   72  72   72  79  79  73  73  70   69  76  76  70   73   73      10
# 2   71  69   69  76  76  71  71  67   73  78  78  78   77   77       0
# 3   75  66   66  69  69  68  68  61   60  68  68  61   69   69       0
# 4   67  63   63  75  75  65  65  58   57  70  70  59   67   67       0
# 5   63  60   60  75  75  62  62  55   58  71  71  61   66   66       0
# 6   65  56   56  62  62  59  59  53   69  72  72  83   71   71      13
# 7   58  64   64  73  73  65  65  65   65  68  68  62   64   64       0
# 8   56  54   54  55  55  56  56  56   67  62  62  75   62   62       0
# 9   73  65   65  76  76  67  67  58   58  70  70  60   67   67       0
# 10  74  68   68  71  71  68  68  64   65  70  70  67   70   70       6
# 11  76  60   60  53  53  58  58  54   61  57  57  67   58   58       0
# 12  56  59   59  56  56  59  59  63   72  62  62  77   62   62       0
# 13  54  57   57  63  63  61  61  61   70  72  72  78   73   73       0
# 14  62  68   68  69  69  68  68  72   74  72  72  73   73   73      -1
# 15  79  68   68  70  70  68  68  63   73  74  74  82   72   72       0
